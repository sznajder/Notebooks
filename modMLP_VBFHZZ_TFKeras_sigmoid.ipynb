# %% [markdown]
# <a href="https://colab.research.google.com/github/sznajder/Lectures/blob/master/modMLP_VBFHZZ_TFKeras_sigmoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modifyed MLP ( physics aware )with sigmoid output for VBF HZZ4l analysis using  Keras
# Author: Andre Sznajder

# %% [markdown]
# ## **Mount Google Drive**

# %%
# !fusermount -u drive
# !pip install uproot
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
root_dir = "/content/gdrive/My Drive/"
data_dir = "/content/gdrive/My Drive/Colab Notebooks/Data/"
# !ls {data_dir}
# Out:
# fusermount: failed to unmount /content/drive: No such file or directory
# Requirement already satisfied: uproot in /usr/local/lib/python3.6/dist-packages (3.11.3)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.6/dist-packages (from uproot) (1.18.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.6/dist-packages (from uproot) (3.1.1)
# Requirement already satisfied: uproot-methods>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from uproot) (0.7.3)
# Requirement already satisfied: awkward<1.0,>=0.12.0 in /usr/local/lib/python3.6/dist-packages (from uproot) (0.12.20)
# Mounted at /content/gdrive
# ls: cannot access '/content/gdrive/My': No such file or directory
# ls: cannot access 'Drive/Colab': No such file or directory
# ls: cannot access 'Notebooks/Data/': No such file or directory

# %% [markdown]
# #Load data using PANDAS data frames#
# Now we load two different `NumPy` arrays. One corresponding to the VBF H->ZZ->4l signal and the other one corresponds to the full set of backgrounds .

# %%
import numpy as np
import pandas as pd
import h5py

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

filename = {}
upfile = {}
data = {}
df = {}


#data_dir = '/Users/sznajder/Google Drive/Colab Notebooks/Data/'
filename['sig'] = data_dir+'VBFHZZ_signal.csv'
filename['bkg'] = data_dir+'VBFHZZ_background.csv'

# Variables from Roottree to be copyed to PANDA dataframe

VARS = [ 'proc', 'f_run', 'f_event', 'f_weight', \
        'f_massjj', 'f_deltajj', 'f_mass4l', 'f_Z1mass' , 'f_Z2mass', \
        'f_lept1_pdgid', 'f_lept2_pdgid', 'f_lept3_pdgid', 'f_lept4_pdgid', \
        'f_lept1_pt','f_lept1_eta','f_lept1_phi', \
        'f_lept2_pt','f_lept2_eta','f_lept2_phi', \
        'f_lept3_pt','f_lept3_eta','f_lept3_phi', \
        'f_lept4_pt','f_lept4_eta','f_lept4_phi', \
        'f_jet1_pt','f_jet1_eta','f_jet1_phi', \
        'f_jet2_pt','f_jet2_eta','f_jet2_phi', \
        'f_jet3_pt','f_jet3_eta','f_jet3_phi' ]
        
# Read CSV signal and background files into pandas Dataframe
df['sig']  = pd.read_csv(filename['sig'])
df['bkg']  = pd.read_csv(filename['bkg'])
df['sig'].columns = VARS
df['bkg'].columns = VARS

# Crop the background sample to have the same number of events as the signal sample
#df['bkg']=df['bkg'][:len(df['sig'])]

print(len(df['sig']))
print(len(df['bkg']))

# Remove undefined variable entries VARS[i] <= -999
#for i in range(len(VARS)): 
#  df['sig'] = df['sig'][(df['sig'][VARS[i]] > -999)]
#  df['bkg'] = df['bkg'][(df['bkg'][VARS[i]] > -999)]
# Out:
# 28953
# 69596

# %% [markdown]
# **Prepare data for NN input**

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# Add the variable isSignal to the dataframe containing the signal and background events
df['sig']['isSignal']=  np.ones(len(df['sig'])) 
df['bkg']['isSignal'] = np.zeros(len(df['bkg'])) 

print("Number SIG events=", len(df['sig']))
print("Number BKG events=", len(df['bkg']))

# Renormalizes the events weights to give unit sum in the signal and background dataframes
# This is necessary for the NN to learn signal and background in the same proportion , 
#   independently of number of events and absolute weights of events in each sample !
df['sig']['f_weight']=df['sig']['f_weight']/df['sig']['f_weight'].sum(axis=0)
df['bkg']['f_weight']=df['bkg']['f_weight']/df['bkg']['f_weight'].sum(axis=0)


# Concatenate the signal and background in a single  data frames 
df_all = pd.concat([df['sig'],df['bkg']])

# Random shuffles the dataset to mix signal and background events before splitting between train and test samples
df_all = shuffle(df_all)

# Filter dataframe leaving just NN input variables  
NN_VARS = [ 'f_lept1_pdgid', 'f_lept2_pdgid', 'f_lept3_pdgid', 'f_lept4_pdgid', \
            'f_lept1_pt','f_lept1_eta','f_lept1_phi', \
            'f_lept2_pt','f_lept2_eta','f_lept2_phi', \
            'f_lept3_pt','f_lept3_eta','f_lept3_phi', \
            'f_lept4_pt','f_lept4_eta','f_lept4_phi', \
            'f_jet1_pt','f_jet1_eta','f_jet1_phi', \
            'f_jet2_pt','f_jet2_eta','f_jet2_phi']
         
df_input  = df_all.filter(NN_VARS)
df_target = df_all.filter(['isSignal'])
df_weights = df_all.filter(['f_weight'])

# Transform dataframes to numpy arrays of float32 (. X->NN input , Y->NN target output , W-> event weights)
NINPUT=len(NN_VARS)
print("Number NN input variables=",NINPUT)
print("NN input variables=",NN_VARS)
X  = np.asarray( df_input.values ).astype(np.float32)
Y  = np.asarray( df_target.values ).astype(np.float32)
W  = np.asarray( df_weights.values ).astype(np.float32)

# Split the sample into train and test  
X_train_val, X_test, Y_train_val, Y_test , W_train_val , W_test = train_test_split(X, Y, W , test_size=0.2, shuffle=True)


#for i in range(20): print("X_train_val=",X_train_val[i])
#for i in range(20): print("Y_train_val=",Y_train_val[i])
#for i in range(20): print("w_train_val=",W_train_val[i])
# Out:
# Number SIG events= 28953
# Number BKG events= 69596
# Number NN input variables= 22
# NN input variables= ['f_lept1_pdgid', 'f_lept2_pdgid', 'f_lept3_pdgid', 'f_lept4_pdgid', 'f_lept1_pt', 'f_lept1_eta', 'f_lept1_phi', 'f_lept2_pt', 'f_lept2_eta', 'f_lept2_phi', 'f_lept3_pt', 'f_lept3_eta', 'f_lept3_phi', 'f_lept4_pt', 'f_lept4_eta', 'f_lept4_phi', 'f_jet1_pt', 'f_jet1_eta', 'f_jet1_phi', 'f_jet2_pt', 'f_jet2_eta', 'f_jet2_phi']

# %% [markdown]
# ## Define the model using KERAS functional API
# We'll start with a dense (fully-connected) NN layer.
# Our model will have a single fully-connected hidden layer with the same number of neurons as input variables.
# The output layer contains a single neuron using a sigmoid activation in order to a number between 0 and 1 to make binary classification
#
# We are using the `binary_crossentropy` loss function during training, a standard loss function for binary classification problems.
# We will optimize the model with the Adam algorithm for stochastic gradient descent and we will collect accuracy metrics while the model is trained.

# %%
# baseline keras model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import Input, Activation, Dense, Dropout ,  Lambda , concatenate
from tensorflow.keras import utils , backend


def swish(x):
    return backend.sigmoid(x) * x

def crop(dimension, start, end):
    # Crops (or slices) a Tensor on a given dimension from start to end
    # example : to crop tensor x[:, :, 5:10]
    # call slice(2, 5, 10) as you want to crop on the second dimension
    def func(x):
        if dimension == 0:
            return x[start: end]
        if dimension == 1:
            return x[:, start: end]
        if dimension == 2:
            return x[:, :, start: end]
        if dimension == 3:
            return x[:, :, :, start: end]
        if dimension == 4:
            return x[:, :, :, :, start: end]
    return Lambda(func)
  
# Define the NN layers

# Select the NN input variables. Using just lepton and and jets 4-mom ( low level veriables) ! 
nmuon_inputs=16  # ( lept_id , pt , eta , phi of 4 leptons )
njet_inputs=6 # ( pt , eta , phi of 2 tag jets )
input  = Input(shape=(NINPUT,), name = 'input') 

# Slice the input to feed the first leptons layer  
input_lept = crop(1,0,nmuon_inputs)(input)
hidden_lept = Dense(nmuon_inputs*2, name = 'hidden_lept', kernel_initializer='normal', activation='relu')(input_lept)

# Slice the input into leptons and put feed first lepton pair layer 
#input_lept1 = crop(1,0,6)(input)
#hidden_lept1 = Dense(4, name = 'hidden_lept1', kernel_initializer='normal', activation='relu')(input_lept1)

# Slice the input into leptons and put feed second lepton pair layer 
#input_lept2 = crop(1,6,12)(input)
#hidden_lept2 = Dense(4, name = 'hidden_lept2', kernel_initializer='normal', activation='relu')(input_lept2)

# Slice the input to feed first jet layer 
input_jet  = crop(1,nmuon_inputs,nmuon_inputs+njet_inputs)(input)
hidden_jet = Dense(njet_inputs*2, name = 'hidden_jet', kernel_initializer='normal', activation='relu')(input_jet)

# Concatenate the lepton and jet layers into a single hidden layer
#hidden = concatenate([hidden_lept1,hidden_lept2,hidden_jet])
hidden = concatenate([hidden_lept,hidden_jet])

hidden  = Dense((nmuon_inputs+njet_inputs)*2, name = 'hidden1', kernel_initializer='normal', activation='relu')(hidden)

# Define the a single node output layer
output  = Dense(1, name = 'output', kernel_initializer='normal', activation='sigmoid')(hidden)
#output  = Dense(2      , name = 'output', kernel_initializer='normal', activation='softmax')(hidden)

# create the model
model = Model(inputs=input, outputs=output)

# Define the optimizer ( minimization algorithm )

#optim = SGD(lr=0.01,decay=1e-6)
optim = Adam(lr=0.001)

# compile the model
model.compile(optimizer=optim, loss='binary_crossentropy', metrics=['accuracy'], weighted_metrics=['accuracy'])
#model.compile(optimizer=optim, loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])

# print the model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 22)]         0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16)           0           input[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 6)            0           input[0][0]
# __________________________________________________________________________________________________
# hidden_lept (Dense)             (None, 32)           544         lambda_2[0][0]
# __________________________________________________________________________________________________
# hidden_jet (Dense)              (None, 12)           84          lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 44)           0           hidden_lept[0][0]
#                                                                  hidden_jet[0][0]
# __________________________________________________________________________________________________
# hidden1 (Dense)                 (None, 44)           1980        concatenate_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            45          hidden1[0][0]
# ==================================================================================================
# Total params: 2,653
# Trainable params: 2,653
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Prepare DATA by dividing into testing and training dataset and renormalizing events weights
#
# We will split the data into two parts (one for training+validation and one for testing).

# %% [markdown]
# ## Run NN Training

# %%
# Number of training epochs
nepochs=1000
# Batch size
batch=1000
# Train classifier
history = model.fit(X_train_val, 
                    Y_train_val,
                    epochs=nepochs, 
                    sample_weight=W_train_val,
                    batch_size=batch, 
                    verbose=1, # switch to 1 for more verbosity 
                    validation_split=0.3)
# Out:
# Epoch 1/1000
# 56/56 [==============================] - 4s 67ms/step - loss: 1.3952e-05 - accuracy: 0.4046 - weighted_accuracy: 0.5326 - val_loss: 1.3818e-05 - val_accuracy: 0.4607 - val_weighted_accuracy: 0.5835
# Epoch 2/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3774e-05 - accuracy: 0.5346 - weighted_accuracy: 0.5948 - val_loss: 1.3711e-05 - val_accuracy: 0.4980 - val_weighted_accuracy: 0.5987
# Epoch 3/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3770e-05 - accuracy: 0.5637 - weighted_accuracy: 0.5987 - val_loss: 1.3590e-05 - val_accuracy: 0.5976 - val_weighted_accuracy: 0.6023
# Epoch 4/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3602e-05 - accuracy: 0.5750 - weighted_accuracy: 0.6053 - val_loss: 1.3532e-05 - val_accuracy: 0.5920 - val_weighted_accuracy: 0.6051
# Epoch 5/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3559e-05 - accuracy: 0.5719 - weighted_accuracy: 0.6087 - val_loss: 1.3501e-05 - val_accuracy: 0.5651 - val_weighted_accuracy: 0.6042
# Epoch 6/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3552e-05 - accuracy: 0.5644 - weighted_accuracy: 0.6067 - val_loss: 1.3456e-05 - val_accuracy: 0.5722 - val_weighted_accuracy: 0.6110
# Epoch 7/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3485e-05 - accuracy: 0.5600 - weighted_accuracy: 0.6065 - val_loss: 1.3435e-05 - val_accuracy: 0.5864 - val_weighted_accuracy: 0.6092
# Epoch 8/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3459e-05 - accuracy: 0.5670 - weighted_accuracy: 0.6096 - val_loss: 1.3409e-05 - val_accuracy: 0.5616 - val_weighted_accuracy: 0.6087
# Epoch 9/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3426e-05 - accuracy: 0.5645 - weighted_accuracy: 0.6117 - val_loss: 1.3388e-05 - val_accuracy: 0.5519 - val_weighted_accuracy: 0.6148
# Epoch 10/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3438e-05 - accuracy: 0.5641 - weighted_accuracy: 0.6112 - val_loss: 1.3444e-05 - val_accuracy: 0.5097 - val_weighted_accuracy: 0.6060
# Epoch 11/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3393e-05 - accuracy: 0.5694 - weighted_accuracy: 0.6141 - val_loss: 1.3391e-05 - val_accuracy: 0.5214 - val_weighted_accuracy: 0.6111
# Epoch 12/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3338e-05 - accuracy: 0.5752 - weighted_accuracy: 0.6138 - val_loss: 1.3434e-05 - val_accuracy: 0.5060 - val_weighted_accuracy: 0.6063
# Epoch 13/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.3337e-05 - accuracy: 0.5673 - weighted_accuracy: 0.6153 - val_loss: 1.3312e-05 - val_accuracy: 0.6093 - val_weighted_accuracy: 0.6155
# Epoch 14/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3283e-05 - accuracy: 0.5785 - weighted_accuracy: 0.6178 - val_loss: 1.3287e-05 - val_accuracy: 0.5847 - val_weighted_accuracy: 0.6195
# Epoch 15/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3281e-05 - accuracy: 0.5778 - weighted_accuracy: 0.6198 - val_loss: 1.3311e-05 - val_accuracy: 0.5316 - val_weighted_accuracy: 0.6139
# Epoch 16/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3269e-05 - accuracy: 0.5730 - weighted_accuracy: 0.6182 - val_loss: 1.3297e-05 - val_accuracy: 0.5625 - val_weighted_accuracy: 0.6151
# Epoch 17/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3233e-05 - accuracy: 0.5779 - weighted_accuracy: 0.6217 - val_loss: 1.3243e-05 - val_accuracy: 0.5817 - val_weighted_accuracy: 0.6212
# Epoch 18/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3227e-05 - accuracy: 0.5768 - weighted_accuracy: 0.6211 - val_loss: 1.3279e-05 - val_accuracy: 0.6087 - val_weighted_accuracy: 0.6163
# Epoch 19/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3191e-05 - accuracy: 0.5741 - weighted_accuracy: 0.6200 - val_loss: 1.3231e-05 - val_accuracy: 0.6068 - val_weighted_accuracy: 0.6212
# Epoch 20/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.3216e-05 - accuracy: 0.5789 - weighted_accuracy: 0.6198 - val_loss: 1.3205e-05 - val_accuracy: 0.5769 - val_weighted_accuracy: 0.6216
# Epoch 21/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3173e-05 - accuracy: 0.5735 - weighted_accuracy: 0.6206 - val_loss: 1.3196e-05 - val_accuracy: 0.5946 - val_weighted_accuracy: 0.6208
# Epoch 22/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.3169e-05 - accuracy: 0.5768 - weighted_accuracy: 0.6230 - val_loss: 1.3208e-05 - val_accuracy: 0.5490 - val_weighted_accuracy: 0.6172
# Epoch 23/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3149e-05 - accuracy: 0.5783 - weighted_accuracy: 0.6252 - val_loss: 1.3185e-05 - val_accuracy: 0.5498 - val_weighted_accuracy: 0.6220
# Epoch 24/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3131e-05 - accuracy: 0.5757 - weighted_accuracy: 0.6235 - val_loss: 1.3188e-05 - val_accuracy: 0.5510 - val_weighted_accuracy: 0.6211
# Epoch 25/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3119e-05 - accuracy: 0.5735 - weighted_accuracy: 0.6219 - val_loss: 1.3120e-05 - val_accuracy: 0.5810 - val_weighted_accuracy: 0.6193
# Epoch 26/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3067e-05 - accuracy: 0.5746 - weighted_accuracy: 0.6270 - val_loss: 1.3104e-05 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.6214
# Epoch 27/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3069e-05 - accuracy: 0.5749 - weighted_accuracy: 0.6268 - val_loss: 1.3057e-05 - val_accuracy: 0.5757 - val_weighted_accuracy: 0.6286
# Epoch 28/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.2993e-05 - accuracy: 0.5780 - weighted_accuracy: 0.6314 - val_loss: 1.2949e-05 - val_accuracy: 0.5879 - val_weighted_accuracy: 0.6352
# Epoch 29/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.2868e-05 - accuracy: 0.5866 - weighted_accuracy: 0.6384 - val_loss: 1.2831e-05 - val_accuracy: 0.5828 - val_weighted_accuracy: 0.6441
# Epoch 30/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.2681e-05 - accuracy: 0.6027 - weighted_accuracy: 0.6508 - val_loss: 1.2645e-05 - val_accuracy: 0.6297 - val_weighted_accuracy: 0.6526
# Epoch 31/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.2545e-05 - accuracy: 0.6124 - weighted_accuracy: 0.6555 - val_loss: 1.2428e-05 - val_accuracy: 0.6413 - val_weighted_accuracy: 0.6649
# Epoch 32/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.2321e-05 - accuracy: 0.6302 - weighted_accuracy: 0.6650 - val_loss: 1.2307e-05 - val_accuracy: 0.6025 - val_weighted_accuracy: 0.6644
# Epoch 33/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.2125e-05 - accuracy: 0.6455 - weighted_accuracy: 0.6766 - val_loss: 1.2213e-05 - val_accuracy: 0.5945 - val_weighted_accuracy: 0.6651
# Epoch 34/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.1906e-05 - accuracy: 0.6593 - weighted_accuracy: 0.6886 - val_loss: 1.1808e-05 - val_accuracy: 0.6728 - val_weighted_accuracy: 0.6936
# Epoch 35/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.1596e-05 - accuracy: 0.6895 - weighted_accuracy: 0.7114 - val_loss: 1.1507e-05 - val_accuracy: 0.6722 - val_weighted_accuracy: 0.7097
# Epoch 36/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.1282e-05 - accuracy: 0.7158 - weighted_accuracy: 0.7293 - val_loss: 1.1151e-05 - val_accuracy: 0.7272 - val_weighted_accuracy: 0.7310
# Epoch 37/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.1016e-05 - accuracy: 0.7375 - weighted_accuracy: 0.7385 - val_loss: 1.1128e-05 - val_accuracy: 0.7078 - val_weighted_accuracy: 0.7270
# Epoch 38/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0902e-05 - accuracy: 0.7520 - weighted_accuracy: 0.7430 - val_loss: 1.1083e-05 - val_accuracy: 0.7785 - val_weighted_accuracy: 0.7398
# Epoch 39/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0837e-05 - accuracy: 0.7573 - weighted_accuracy: 0.7468 - val_loss: 1.1101e-05 - val_accuracy: 0.7892 - val_weighted_accuracy: 0.7419
# Epoch 40/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0891e-05 - accuracy: 0.7610 - weighted_accuracy: 0.7476 - val_loss: 1.1044e-05 - val_accuracy: 0.7222 - val_weighted_accuracy: 0.7326
# Epoch 41/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0877e-05 - accuracy: 0.7593 - weighted_accuracy: 0.7448 - val_loss: 1.1344e-05 - val_accuracy: 0.6744 - val_weighted_accuracy: 0.7116
# Epoch 42/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0846e-05 - accuracy: 0.7563 - weighted_accuracy: 0.7431 - val_loss: 1.0885e-05 - val_accuracy: 0.7677 - val_weighted_accuracy: 0.7447
# Epoch 43/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0715e-05 - accuracy: 0.7673 - weighted_accuracy: 0.7509 - val_loss: 1.0878e-05 - val_accuracy: 0.7583 - val_weighted_accuracy: 0.7397
# Epoch 44/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0734e-05 - accuracy: 0.7668 - weighted_accuracy: 0.7496 - val_loss: 1.1082e-05 - val_accuracy: 0.7045 - val_weighted_accuracy: 0.7230
# Epoch 45/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0739e-05 - accuracy: 0.7652 - weighted_accuracy: 0.7501 - val_loss: 1.0961e-05 - val_accuracy: 0.7252 - val_weighted_accuracy: 0.7318
# Epoch 46/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0671e-05 - accuracy: 0.7685 - weighted_accuracy: 0.7529 - val_loss: 1.0845e-05 - val_accuracy: 0.7811 - val_weighted_accuracy: 0.7448
# Epoch 47/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0694e-05 - accuracy: 0.7680 - weighted_accuracy: 0.7495 - val_loss: 1.0888e-05 - val_accuracy: 0.7334 - val_weighted_accuracy: 0.7356
# Epoch 48/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0634e-05 - accuracy: 0.7702 - weighted_accuracy: 0.7515 - val_loss: 1.0790e-05 - val_accuracy: 0.7762 - val_weighted_accuracy: 0.7469
# Epoch 49/1000
# 56/56 [==============================] - 4s 64ms/step - loss: 1.0654e-05 - accuracy: 0.7716 - weighted_accuracy: 0.7521 - val_loss: 1.0835e-05 - val_accuracy: 0.7837 - val_weighted_accuracy: 0.7488
# Epoch 50/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0643e-05 - accuracy: 0.7706 - weighted_accuracy: 0.7519 - val_loss: 1.0798e-05 - val_accuracy: 0.7856 - val_weighted_accuracy: 0.7515
# Epoch 51/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0634e-05 - accuracy: 0.7730 - weighted_accuracy: 0.7532 - val_loss: 1.0761e-05 - val_accuracy: 0.7802 - val_weighted_accuracy: 0.7517
# Epoch 52/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0613e-05 - accuracy: 0.7734 - weighted_accuracy: 0.7539 - val_loss: 1.0738e-05 - val_accuracy: 0.7800 - val_weighted_accuracy: 0.7481
# Epoch 53/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0632e-05 - accuracy: 0.7737 - weighted_accuracy: 0.7536 - val_loss: 1.0911e-05 - val_accuracy: 0.7956 - val_weighted_accuracy: 0.7485
# Epoch 54/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0597e-05 - accuracy: 0.7736 - weighted_accuracy: 0.7533 - val_loss: 1.0740e-05 - val_accuracy: 0.7782 - val_weighted_accuracy: 0.7519
# Epoch 55/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0579e-05 - accuracy: 0.7757 - weighted_accuracy: 0.7531 - val_loss: 1.0822e-05 - val_accuracy: 0.7539 - val_weighted_accuracy: 0.7413
# Epoch 56/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0615e-05 - accuracy: 0.7751 - weighted_accuracy: 0.7543 - val_loss: 1.0719e-05 - val_accuracy: 0.7665 - val_weighted_accuracy: 0.7469
# Epoch 57/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0582e-05 - accuracy: 0.7736 - weighted_accuracy: 0.7540 - val_loss: 1.0734e-05 - val_accuracy: 0.7746 - val_weighted_accuracy: 0.7500
# Epoch 58/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0583e-05 - accuracy: 0.7754 - weighted_accuracy: 0.7553 - val_loss: 1.0744e-05 - val_accuracy: 0.7845 - val_weighted_accuracy: 0.7497
# Epoch 59/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0550e-05 - accuracy: 0.7756 - weighted_accuracy: 0.7527 - val_loss: 1.0713e-05 - val_accuracy: 0.7746 - val_weighted_accuracy: 0.7504
# Epoch 60/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0579e-05 - accuracy: 0.7753 - weighted_accuracy: 0.7546 - val_loss: 1.0763e-05 - val_accuracy: 0.7533 - val_weighted_accuracy: 0.7440
# Epoch 61/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0562e-05 - accuracy: 0.7736 - weighted_accuracy: 0.7531 - val_loss: 1.0705e-05 - val_accuracy: 0.7832 - val_weighted_accuracy: 0.7500
# Epoch 62/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0503e-05 - accuracy: 0.7774 - weighted_accuracy: 0.7554 - val_loss: 1.0704e-05 - val_accuracy: 0.7695 - val_weighted_accuracy: 0.7501
# Epoch 63/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0547e-05 - accuracy: 0.7758 - weighted_accuracy: 0.7540 - val_loss: 1.0718e-05 - val_accuracy: 0.7758 - val_weighted_accuracy: 0.7491
# Epoch 64/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0526e-05 - accuracy: 0.7776 - weighted_accuracy: 0.7547 - val_loss: 1.0722e-05 - val_accuracy: 0.7658 - val_weighted_accuracy: 0.7475
# Epoch 65/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0534e-05 - accuracy: 0.7776 - weighted_accuracy: 0.7552 - val_loss: 1.0681e-05 - val_accuracy: 0.7707 - val_weighted_accuracy: 0.7504
# Epoch 66/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0514e-05 - accuracy: 0.7759 - weighted_accuracy: 0.7539 - val_loss: 1.0711e-05 - val_accuracy: 0.7614 - val_weighted_accuracy: 0.7468
# Epoch 67/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0503e-05 - accuracy: 0.7777 - weighted_accuracy: 0.7559 - val_loss: 1.0749e-05 - val_accuracy: 0.7838 - val_weighted_accuracy: 0.7517
# Epoch 68/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0509e-05 - accuracy: 0.7768 - weighted_accuracy: 0.7551 - val_loss: 1.0688e-05 - val_accuracy: 0.7825 - val_weighted_accuracy: 0.7520
# Epoch 69/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0519e-05 - accuracy: 0.7787 - weighted_accuracy: 0.7546 - val_loss: 1.0799e-05 - val_accuracy: 0.7468 - val_weighted_accuracy: 0.7427
# Epoch 70/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0539e-05 - accuracy: 0.7745 - weighted_accuracy: 0.7537 - val_loss: 1.0760e-05 - val_accuracy: 0.7786 - val_weighted_accuracy: 0.7493
# Epoch 71/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0509e-05 - accuracy: 0.7761 - weighted_accuracy: 0.7552 - val_loss: 1.0683e-05 - val_accuracy: 0.7678 - val_weighted_accuracy: 0.7488
# Epoch 72/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0491e-05 - accuracy: 0.7776 - weighted_accuracy: 0.7539 - val_loss: 1.0661e-05 - val_accuracy: 0.7760 - val_weighted_accuracy: 0.7511
# Epoch 73/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0556e-05 - accuracy: 0.7765 - weighted_accuracy: 0.7530 - val_loss: 1.0675e-05 - val_accuracy: 0.7813 - val_weighted_accuracy: 0.7523
# Epoch 74/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0538e-05 - accuracy: 0.7737 - weighted_accuracy: 0.7524 - val_loss: 1.0655e-05 - val_accuracy: 0.7813 - val_weighted_accuracy: 0.7520
# Epoch 75/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0515e-05 - accuracy: 0.7779 - weighted_accuracy: 0.7536 - val_loss: 1.0675e-05 - val_accuracy: 0.7849 - val_weighted_accuracy: 0.7520
# Epoch 76/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0486e-05 - accuracy: 0.7778 - weighted_accuracy: 0.7548 - val_loss: 1.0733e-05 - val_accuracy: 0.7909 - val_weighted_accuracy: 0.7520
# Epoch 77/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0499e-05 - accuracy: 0.7799 - weighted_accuracy: 0.7563 - val_loss: 1.0643e-05 - val_accuracy: 0.7833 - val_weighted_accuracy: 0.7525
# Epoch 78/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0483e-05 - accuracy: 0.7774 - weighted_accuracy: 0.7554 - val_loss: 1.0645e-05 - val_accuracy: 0.7722 - val_weighted_accuracy: 0.7507
# Epoch 79/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0499e-05 - accuracy: 0.7791 - weighted_accuracy: 0.7536 - val_loss: 1.0694e-05 - val_accuracy: 0.7656 - val_weighted_accuracy: 0.7478
# Epoch 80/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0468e-05 - accuracy: 0.7795 - weighted_accuracy: 0.7551 - val_loss: 1.0660e-05 - val_accuracy: 0.7808 - val_weighted_accuracy: 0.7503
# Epoch 81/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0516e-05 - accuracy: 0.7756 - weighted_accuracy: 0.7532 - val_loss: 1.0712e-05 - val_accuracy: 0.7913 - val_weighted_accuracy: 0.7504
# Epoch 82/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0443e-05 - accuracy: 0.7804 - weighted_accuracy: 0.7559 - val_loss: 1.0646e-05 - val_accuracy: 0.7767 - val_weighted_accuracy: 0.7501
# Epoch 83/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0465e-05 - accuracy: 0.7788 - weighted_accuracy: 0.7545 - val_loss: 1.0635e-05 - val_accuracy: 0.7748 - val_weighted_accuracy: 0.7509
# Epoch 84/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0484e-05 - accuracy: 0.7793 - weighted_accuracy: 0.7548 - val_loss: 1.0721e-05 - val_accuracy: 0.7544 - val_weighted_accuracy: 0.7436
# Epoch 85/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0452e-05 - accuracy: 0.7776 - weighted_accuracy: 0.7543 - val_loss: 1.0638e-05 - val_accuracy: 0.7769 - val_weighted_accuracy: 0.7504
# Epoch 86/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0468e-05 - accuracy: 0.7782 - weighted_accuracy: 0.7542 - val_loss: 1.0629e-05 - val_accuracy: 0.7689 - val_weighted_accuracy: 0.7499
# Epoch 87/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0483e-05 - accuracy: 0.7779 - weighted_accuracy: 0.7534 - val_loss: 1.0627e-05 - val_accuracy: 0.7716 - val_weighted_accuracy: 0.7501
# Epoch 88/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0442e-05 - accuracy: 0.7807 - weighted_accuracy: 0.7574 - val_loss: 1.0633e-05 - val_accuracy: 0.7871 - val_weighted_accuracy: 0.7527
# Epoch 89/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0464e-05 - accuracy: 0.7803 - weighted_accuracy: 0.7556 - val_loss: 1.0711e-05 - val_accuracy: 0.7899 - val_weighted_accuracy: 0.7512
# Epoch 90/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0500e-05 - accuracy: 0.7806 - weighted_accuracy: 0.7567 - val_loss: 1.0618e-05 - val_accuracy: 0.7811 - val_weighted_accuracy: 0.7498
# Epoch 91/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0456e-05 - accuracy: 0.7814 - weighted_accuracy: 0.7568 - val_loss: 1.0628e-05 - val_accuracy: 0.7779 - val_weighted_accuracy: 0.7520
# Epoch 92/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0404e-05 - accuracy: 0.7795 - weighted_accuracy: 0.7552 - val_loss: 1.0639e-05 - val_accuracy: 0.7759 - val_weighted_accuracy: 0.7525
# Epoch 93/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0511e-05 - accuracy: 0.7803 - weighted_accuracy: 0.7565 - val_loss: 1.0635e-05 - val_accuracy: 0.7795 - val_weighted_accuracy: 0.7512
# Epoch 94/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0425e-05 - accuracy: 0.7818 - weighted_accuracy: 0.7565 - val_loss: 1.0681e-05 - val_accuracy: 0.7634 - val_weighted_accuracy: 0.7466
# Epoch 95/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0413e-05 - accuracy: 0.7794 - weighted_accuracy: 0.7561 - val_loss: 1.0612e-05 - val_accuracy: 0.7783 - val_weighted_accuracy: 0.7511
# Epoch 96/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0397e-05 - accuracy: 0.7808 - weighted_accuracy: 0.7571 - val_loss: 1.0616e-05 - val_accuracy: 0.7792 - val_weighted_accuracy: 0.7515
# Epoch 97/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0396e-05 - accuracy: 0.7818 - weighted_accuracy: 0.7566 - val_loss: 1.0616e-05 - val_accuracy: 0.7850 - val_weighted_accuracy: 0.7537
# Epoch 98/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0431e-05 - accuracy: 0.7815 - weighted_accuracy: 0.7571 - val_loss: 1.0634e-05 - val_accuracy: 0.7825 - val_weighted_accuracy: 0.7517
# Epoch 99/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0353e-05 - accuracy: 0.7822 - weighted_accuracy: 0.7572 - val_loss: 1.0586e-05 - val_accuracy: 0.7751 - val_weighted_accuracy: 0.7519
# Epoch 100/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0408e-05 - accuracy: 0.7818 - weighted_accuracy: 0.7579 - val_loss: 1.0620e-05 - val_accuracy: 0.7893 - val_weighted_accuracy: 0.7531
# Epoch 101/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0391e-05 - accuracy: 0.7819 - weighted_accuracy: 0.7554 - val_loss: 1.0836e-05 - val_accuracy: 0.7383 - val_weighted_accuracy: 0.7390
# Epoch 102/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0394e-05 - accuracy: 0.7794 - weighted_accuracy: 0.7570 - val_loss: 1.0580e-05 - val_accuracy: 0.7810 - val_weighted_accuracy: 0.7529
# Epoch 103/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0355e-05 - accuracy: 0.7814 - weighted_accuracy: 0.7566 - val_loss: 1.0590e-05 - val_accuracy: 0.7868 - val_weighted_accuracy: 0.7534
# Epoch 104/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0353e-05 - accuracy: 0.7834 - weighted_accuracy: 0.7573 - val_loss: 1.0653e-05 - val_accuracy: 0.7601 - val_weighted_accuracy: 0.7452
# Epoch 105/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0379e-05 - accuracy: 0.7820 - weighted_accuracy: 0.7583 - val_loss: 1.0675e-05 - val_accuracy: 0.7955 - val_weighted_accuracy: 0.7530
# Epoch 106/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0407e-05 - accuracy: 0.7824 - weighted_accuracy: 0.7569 - val_loss: 1.0608e-05 - val_accuracy: 0.7675 - val_weighted_accuracy: 0.7488
# Epoch 107/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0378e-05 - accuracy: 0.7801 - weighted_accuracy: 0.7566 - val_loss: 1.0605e-05 - val_accuracy: 0.7840 - val_weighted_accuracy: 0.7505
# Epoch 108/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0381e-05 - accuracy: 0.7800 - weighted_accuracy: 0.7566 - val_loss: 1.0564e-05 - val_accuracy: 0.7756 - val_weighted_accuracy: 0.7514
# Epoch 109/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0396e-05 - accuracy: 0.7825 - weighted_accuracy: 0.7570 - val_loss: 1.0562e-05 - val_accuracy: 0.7788 - val_weighted_accuracy: 0.7537
# Epoch 110/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0372e-05 - accuracy: 0.7811 - weighted_accuracy: 0.7569 - val_loss: 1.0581e-05 - val_accuracy: 0.7861 - val_weighted_accuracy: 0.7537
# Epoch 111/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0352e-05 - accuracy: 0.7835 - weighted_accuracy: 0.7584 - val_loss: 1.0604e-05 - val_accuracy: 0.7638 - val_weighted_accuracy: 0.7479
# Epoch 112/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0375e-05 - accuracy: 0.7813 - weighted_accuracy: 0.7566 - val_loss: 1.0589e-05 - val_accuracy: 0.7771 - val_weighted_accuracy: 0.7516
# Epoch 113/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0339e-05 - accuracy: 0.7834 - weighted_accuracy: 0.7581 - val_loss: 1.0561e-05 - val_accuracy: 0.7901 - val_weighted_accuracy: 0.7540
# Epoch 114/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0385e-05 - accuracy: 0.7825 - weighted_accuracy: 0.7565 - val_loss: 1.0611e-05 - val_accuracy: 0.7817 - val_weighted_accuracy: 0.7519
# Epoch 115/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0428e-05 - accuracy: 0.7793 - weighted_accuracy: 0.7561 - val_loss: 1.0555e-05 - val_accuracy: 0.7782 - val_weighted_accuracy: 0.7524
# Epoch 116/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0299e-05 - accuracy: 0.7826 - weighted_accuracy: 0.7590 - val_loss: 1.0616e-05 - val_accuracy: 0.7945 - val_weighted_accuracy: 0.7526
# Epoch 117/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0332e-05 - accuracy: 0.7829 - weighted_accuracy: 0.7590 - val_loss: 1.0595e-05 - val_accuracy: 0.7811 - val_weighted_accuracy: 0.7527
# Epoch 118/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0338e-05 - accuracy: 0.7831 - weighted_accuracy: 0.7577 - val_loss: 1.0591e-05 - val_accuracy: 0.7864 - val_weighted_accuracy: 0.7553
# Epoch 119/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0330e-05 - accuracy: 0.7824 - weighted_accuracy: 0.7579 - val_loss: 1.0556e-05 - val_accuracy: 0.7855 - val_weighted_accuracy: 0.7519
# Epoch 120/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0334e-05 - accuracy: 0.7843 - weighted_accuracy: 0.7587 - val_loss: 1.0554e-05 - val_accuracy: 0.7832 - val_weighted_accuracy: 0.7528
# Epoch 121/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0342e-05 - accuracy: 0.7832 - weighted_accuracy: 0.7583 - val_loss: 1.0655e-05 - val_accuracy: 0.7970 - val_weighted_accuracy: 0.7513
# Epoch 122/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0300e-05 - accuracy: 0.7826 - weighted_accuracy: 0.7576 - val_loss: 1.0531e-05 - val_accuracy: 0.7867 - val_weighted_accuracy: 0.7538
# Epoch 123/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0299e-05 - accuracy: 0.7844 - weighted_accuracy: 0.7599 - val_loss: 1.0541e-05 - val_accuracy: 0.7827 - val_weighted_accuracy: 0.7542
# Epoch 124/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0285e-05 - accuracy: 0.7828 - weighted_accuracy: 0.7580 - val_loss: 1.0687e-05 - val_accuracy: 0.7978 - val_weighted_accuracy: 0.7506
# Epoch 125/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0394e-05 - accuracy: 0.7810 - weighted_accuracy: 0.7585 - val_loss: 1.0567e-05 - val_accuracy: 0.7784 - val_weighted_accuracy: 0.7534
# Epoch 126/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0297e-05 - accuracy: 0.7819 - weighted_accuracy: 0.7586 - val_loss: 1.0616e-05 - val_accuracy: 0.7567 - val_weighted_accuracy: 0.7452
# Epoch 127/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0302e-05 - accuracy: 0.7826 - weighted_accuracy: 0.7591 - val_loss: 1.0529e-05 - val_accuracy: 0.7735 - val_weighted_accuracy: 0.7523
# Epoch 128/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0259e-05 - accuracy: 0.7848 - weighted_accuracy: 0.7595 - val_loss: 1.0533e-05 - val_accuracy: 0.7834 - val_weighted_accuracy: 0.7543
# Epoch 129/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0282e-05 - accuracy: 0.7838 - weighted_accuracy: 0.7599 - val_loss: 1.0583e-05 - val_accuracy: 0.7959 - val_weighted_accuracy: 0.7548
# Epoch 130/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0322e-05 - accuracy: 0.7827 - weighted_accuracy: 0.7588 - val_loss: 1.0511e-05 - val_accuracy: 0.7899 - val_weighted_accuracy: 0.7576
# Epoch 131/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0231e-05 - accuracy: 0.7852 - weighted_accuracy: 0.7603 - val_loss: 1.0519e-05 - val_accuracy: 0.7791 - val_weighted_accuracy: 0.7526
# Epoch 132/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0298e-05 - accuracy: 0.7840 - weighted_accuracy: 0.7592 - val_loss: 1.0537e-05 - val_accuracy: 0.7891 - val_weighted_accuracy: 0.7562
# Epoch 133/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0263e-05 - accuracy: 0.7849 - weighted_accuracy: 0.7594 - val_loss: 1.0582e-05 - val_accuracy: 0.7613 - val_weighted_accuracy: 0.7484
# Epoch 134/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0286e-05 - accuracy: 0.7845 - weighted_accuracy: 0.7599 - val_loss: 1.0518e-05 - val_accuracy: 0.7741 - val_weighted_accuracy: 0.7511
# Epoch 135/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0244e-05 - accuracy: 0.7834 - weighted_accuracy: 0.7595 - val_loss: 1.0509e-05 - val_accuracy: 0.7788 - val_weighted_accuracy: 0.7542
# Epoch 136/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0258e-05 - accuracy: 0.7849 - weighted_accuracy: 0.7601 - val_loss: 1.0513e-05 - val_accuracy: 0.7732 - val_weighted_accuracy: 0.7518
# Epoch 137/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0251e-05 - accuracy: 0.7837 - weighted_accuracy: 0.7605 - val_loss: 1.0559e-05 - val_accuracy: 0.7965 - val_weighted_accuracy: 0.7552
# Epoch 138/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0278e-05 - accuracy: 0.7844 - weighted_accuracy: 0.7595 - val_loss: 1.0534e-05 - val_accuracy: 0.7704 - val_weighted_accuracy: 0.7509
# Epoch 139/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0310e-05 - accuracy: 0.7809 - weighted_accuracy: 0.7586 - val_loss: 1.0512e-05 - val_accuracy: 0.7717 - val_weighted_accuracy: 0.7527
# Epoch 140/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0211e-05 - accuracy: 0.7841 - weighted_accuracy: 0.7601 - val_loss: 1.0623e-05 - val_accuracy: 0.7970 - val_weighted_accuracy: 0.7548
# Epoch 141/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0227e-05 - accuracy: 0.7853 - weighted_accuracy: 0.7604 - val_loss: 1.0569e-05 - val_accuracy: 0.7656 - val_weighted_accuracy: 0.7490
# Epoch 142/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0246e-05 - accuracy: 0.7854 - weighted_accuracy: 0.7618 - val_loss: 1.0486e-05 - val_accuracy: 0.7811 - val_weighted_accuracy: 0.7554
# Epoch 143/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0235e-05 - accuracy: 0.7847 - weighted_accuracy: 0.7599 - val_loss: 1.0542e-05 - val_accuracy: 0.7665 - val_weighted_accuracy: 0.7502
# Epoch 144/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0262e-05 - accuracy: 0.7814 - weighted_accuracy: 0.7587 - val_loss: 1.0538e-05 - val_accuracy: 0.7788 - val_weighted_accuracy: 0.7532
# Epoch 145/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0257e-05 - accuracy: 0.7856 - weighted_accuracy: 0.7610 - val_loss: 1.0509e-05 - val_accuracy: 0.7775 - val_weighted_accuracy: 0.7538
# Epoch 146/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0271e-05 - accuracy: 0.7824 - weighted_accuracy: 0.7598 - val_loss: 1.0545e-05 - val_accuracy: 0.7882 - val_weighted_accuracy: 0.7566
# Epoch 147/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0230e-05 - accuracy: 0.7854 - weighted_accuracy: 0.7613 - val_loss: 1.0616e-05 - val_accuracy: 0.7983 - val_weighted_accuracy: 0.7549
# Epoch 148/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0246e-05 - accuracy: 0.7841 - weighted_accuracy: 0.7611 - val_loss: 1.0780e-05 - val_accuracy: 0.8028 - val_weighted_accuracy: 0.7485
# Epoch 149/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0338e-05 - accuracy: 0.7811 - weighted_accuracy: 0.7592 - val_loss: 1.0585e-05 - val_accuracy: 0.7961 - val_weighted_accuracy: 0.7543
# Epoch 150/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0222e-05 - accuracy: 0.7858 - weighted_accuracy: 0.7613 - val_loss: 1.0498e-05 - val_accuracy: 0.7855 - val_weighted_accuracy: 0.7556
# Epoch 151/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0205e-05 - accuracy: 0.7873 - weighted_accuracy: 0.7632 - val_loss: 1.0502e-05 - val_accuracy: 0.7867 - val_weighted_accuracy: 0.7550
# Epoch 152/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0202e-05 - accuracy: 0.7871 - weighted_accuracy: 0.7627 - val_loss: 1.0478e-05 - val_accuracy: 0.7812 - val_weighted_accuracy: 0.7551
# Epoch 153/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0208e-05 - accuracy: 0.7858 - weighted_accuracy: 0.7612 - val_loss: 1.0532e-05 - val_accuracy: 0.7918 - val_weighted_accuracy: 0.7546
# Epoch 154/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0225e-05 - accuracy: 0.7867 - weighted_accuracy: 0.7625 - val_loss: 1.0498e-05 - val_accuracy: 0.7844 - val_weighted_accuracy: 0.7580
# Epoch 155/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0176e-05 - accuracy: 0.7841 - weighted_accuracy: 0.7622 - val_loss: 1.0798e-05 - val_accuracy: 0.8047 - val_weighted_accuracy: 0.7476
# Epoch 156/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0307e-05 - accuracy: 0.7837 - weighted_accuracy: 0.7597 - val_loss: 1.0542e-05 - val_accuracy: 0.7956 - val_weighted_accuracy: 0.7562
# Epoch 157/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0188e-05 - accuracy: 0.7860 - weighted_accuracy: 0.7613 - val_loss: 1.0515e-05 - val_accuracy: 0.7843 - val_weighted_accuracy: 0.7559
# Epoch 158/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0194e-05 - accuracy: 0.7860 - weighted_accuracy: 0.7618 - val_loss: 1.0518e-05 - val_accuracy: 0.7789 - val_weighted_accuracy: 0.7533
# Epoch 159/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0174e-05 - accuracy: 0.7855 - weighted_accuracy: 0.7617 - val_loss: 1.0593e-05 - val_accuracy: 0.7988 - val_weighted_accuracy: 0.7537
# Epoch 160/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0253e-05 - accuracy: 0.7869 - weighted_accuracy: 0.7623 - val_loss: 1.0502e-05 - val_accuracy: 0.7907 - val_weighted_accuracy: 0.7549
# Epoch 161/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0174e-05 - accuracy: 0.7864 - weighted_accuracy: 0.7627 - val_loss: 1.0684e-05 - val_accuracy: 0.8023 - val_weighted_accuracy: 0.7522
# Epoch 162/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0252e-05 - accuracy: 0.7850 - weighted_accuracy: 0.7625 - val_loss: 1.0602e-05 - val_accuracy: 0.7958 - val_weighted_accuracy: 0.7526
# Epoch 163/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0187e-05 - accuracy: 0.7857 - weighted_accuracy: 0.7615 - val_loss: 1.0523e-05 - val_accuracy: 0.7700 - val_weighted_accuracy: 0.7517
# Epoch 164/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0204e-05 - accuracy: 0.7863 - weighted_accuracy: 0.7621 - val_loss: 1.0522e-05 - val_accuracy: 0.7757 - val_weighted_accuracy: 0.7537
# Epoch 165/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0185e-05 - accuracy: 0.7867 - weighted_accuracy: 0.7631 - val_loss: 1.0630e-05 - val_accuracy: 0.7953 - val_weighted_accuracy: 0.7530
# Epoch 166/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0202e-05 - accuracy: 0.7864 - weighted_accuracy: 0.7626 - val_loss: 1.0699e-05 - val_accuracy: 0.7439 - val_weighted_accuracy: 0.7420
# Epoch 167/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0207e-05 - accuracy: 0.7851 - weighted_accuracy: 0.7628 - val_loss: 1.0501e-05 - val_accuracy: 0.7830 - val_weighted_accuracy: 0.7545
# Epoch 168/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0167e-05 - accuracy: 0.7873 - weighted_accuracy: 0.7631 - val_loss: 1.0502e-05 - val_accuracy: 0.7905 - val_weighted_accuracy: 0.7559
# Epoch 169/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0173e-05 - accuracy: 0.7842 - weighted_accuracy: 0.7608 - val_loss: 1.0536e-05 - val_accuracy: 0.7925 - val_weighted_accuracy: 0.7554
# Epoch 170/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0198e-05 - accuracy: 0.7847 - weighted_accuracy: 0.7609 - val_loss: 1.0547e-05 - val_accuracy: 0.7622 - val_weighted_accuracy: 0.7480
# Epoch 171/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0210e-05 - accuracy: 0.7849 - weighted_accuracy: 0.7616 - val_loss: 1.0537e-05 - val_accuracy: 0.7678 - val_weighted_accuracy: 0.7501
# Epoch 172/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0161e-05 - accuracy: 0.7869 - weighted_accuracy: 0.7630 - val_loss: 1.0534e-05 - val_accuracy: 0.7951 - val_weighted_accuracy: 0.7543
# Epoch 173/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0150e-05 - accuracy: 0.7872 - weighted_accuracy: 0.7630 - val_loss: 1.0489e-05 - val_accuracy: 0.7850 - val_weighted_accuracy: 0.7560
# Epoch 174/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0197e-05 - accuracy: 0.7870 - weighted_accuracy: 0.7630 - val_loss: 1.0544e-05 - val_accuracy: 0.7659 - val_weighted_accuracy: 0.7484
# Epoch 175/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0224e-05 - accuracy: 0.7834 - weighted_accuracy: 0.7611 - val_loss: 1.0504e-05 - val_accuracy: 0.7756 - val_weighted_accuracy: 0.7537
# Epoch 176/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0171e-05 - accuracy: 0.7874 - weighted_accuracy: 0.7656 - val_loss: 1.0499e-05 - val_accuracy: 0.7722 - val_weighted_accuracy: 0.7526
# Epoch 177/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0132e-05 - accuracy: 0.7869 - weighted_accuracy: 0.7630 - val_loss: 1.0589e-05 - val_accuracy: 0.7988 - val_weighted_accuracy: 0.7542
# Epoch 178/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0163e-05 - accuracy: 0.7871 - weighted_accuracy: 0.7629 - val_loss: 1.0565e-05 - val_accuracy: 0.7935 - val_weighted_accuracy: 0.7555
# Epoch 179/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0200e-05 - accuracy: 0.7858 - weighted_accuracy: 0.7610 - val_loss: 1.0628e-05 - val_accuracy: 0.7539 - val_weighted_accuracy: 0.7452
# Epoch 180/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0184e-05 - accuracy: 0.7850 - weighted_accuracy: 0.7623 - val_loss: 1.0558e-05 - val_accuracy: 0.7752 - val_weighted_accuracy: 0.7544
# Epoch 181/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0188e-05 - accuracy: 0.7873 - weighted_accuracy: 0.7629 - val_loss: 1.0606e-05 - val_accuracy: 0.7567 - val_weighted_accuracy: 0.7469
# Epoch 182/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0162e-05 - accuracy: 0.7853 - weighted_accuracy: 0.7624 - val_loss: 1.0612e-05 - val_accuracy: 0.7796 - val_weighted_accuracy: 0.7519
# Epoch 183/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0180e-05 - accuracy: 0.7864 - weighted_accuracy: 0.7639 - val_loss: 1.0536e-05 - val_accuracy: 0.7650 - val_weighted_accuracy: 0.7505
# Epoch 184/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0170e-05 - accuracy: 0.7854 - weighted_accuracy: 0.7642 - val_loss: 1.0493e-05 - val_accuracy: 0.7771 - val_weighted_accuracy: 0.7552
# Epoch 185/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0140e-05 - accuracy: 0.7860 - weighted_accuracy: 0.7646 - val_loss: 1.0660e-05 - val_accuracy: 0.8007 - val_weighted_accuracy: 0.7524
# Epoch 186/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0154e-05 - accuracy: 0.7880 - weighted_accuracy: 0.7638 - val_loss: 1.0501e-05 - val_accuracy: 0.7884 - val_weighted_accuracy: 0.7575
# Epoch 187/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0118e-05 - accuracy: 0.7866 - weighted_accuracy: 0.7630 - val_loss: 1.0559e-05 - val_accuracy: 0.7973 - val_weighted_accuracy: 0.7555
# Epoch 188/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 1.0123e-05 - accuracy: 0.7877 - weighted_accuracy: 0.7646 - val_loss: 1.0498e-05 - val_accuracy: 0.7918 - val_weighted_accuracy: 0.7569
# Epoch 189/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0159e-05 - accuracy: 0.7864 - weighted_accuracy: 0.7638 - val_loss: 1.0548e-05 - val_accuracy: 0.7698 - val_weighted_accuracy: 0.7503
# Epoch 190/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0127e-05 - accuracy: 0.7884 - weighted_accuracy: 0.7645 - val_loss: 1.0523e-05 - val_accuracy: 0.7898 - val_weighted_accuracy: 0.7564
# Epoch 191/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0195e-05 - accuracy: 0.7828 - weighted_accuracy: 0.7616 - val_loss: 1.0573e-05 - val_accuracy: 0.7963 - val_weighted_accuracy: 0.7564
# Epoch 192/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0177e-05 - accuracy: 0.7849 - weighted_accuracy: 0.7622 - val_loss: 1.0494e-05 - val_accuracy: 0.7852 - val_weighted_accuracy: 0.7553
# Epoch 193/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0121e-05 - accuracy: 0.7874 - weighted_accuracy: 0.7638 - val_loss: 1.0535e-05 - val_accuracy: 0.7639 - val_weighted_accuracy: 0.7493
# Epoch 194/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0186e-05 - accuracy: 0.7854 - weighted_accuracy: 0.7629 - val_loss: 1.0489e-05 - val_accuracy: 0.7776 - val_weighted_accuracy: 0.7545
# Epoch 195/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0158e-05 - accuracy: 0.7865 - weighted_accuracy: 0.7637 - val_loss: 1.0569e-05 - val_accuracy: 0.7889 - val_weighted_accuracy: 0.7551
# Epoch 196/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0127e-05 - accuracy: 0.7880 - weighted_accuracy: 0.7639 - val_loss: 1.0509e-05 - val_accuracy: 0.7736 - val_weighted_accuracy: 0.7524
# Epoch 197/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0182e-05 - accuracy: 0.7867 - weighted_accuracy: 0.7630 - val_loss: 1.0568e-05 - val_accuracy: 0.7963 - val_weighted_accuracy: 0.7564
# Epoch 198/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0158e-05 - accuracy: 0.7861 - weighted_accuracy: 0.7639 - val_loss: 1.0526e-05 - val_accuracy: 0.7712 - val_weighted_accuracy: 0.7520
# Epoch 199/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0165e-05 - accuracy: 0.7871 - weighted_accuracy: 0.7648 - val_loss: 1.0501e-05 - val_accuracy: 0.7893 - val_weighted_accuracy: 0.7571
# Epoch 200/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0152e-05 - accuracy: 0.7881 - weighted_accuracy: 0.7656 - val_loss: 1.0507e-05 - val_accuracy: 0.7900 - val_weighted_accuracy: 0.7547
# Epoch 201/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0190e-05 - accuracy: 0.7830 - weighted_accuracy: 0.7615 - val_loss: 1.0729e-05 - val_accuracy: 0.8061 - val_weighted_accuracy: 0.7520
# Epoch 202/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0192e-05 - accuracy: 0.7871 - weighted_accuracy: 0.7648 - val_loss: 1.0503e-05 - val_accuracy: 0.7813 - val_weighted_accuracy: 0.7542
# Epoch 203/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0149e-05 - accuracy: 0.7865 - weighted_accuracy: 0.7633 - val_loss: 1.0509e-05 - val_accuracy: 0.7921 - val_weighted_accuracy: 0.7558
# Epoch 204/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0115e-05 - accuracy: 0.7888 - weighted_accuracy: 0.7655 - val_loss: 1.0504e-05 - val_accuracy: 0.7848 - val_weighted_accuracy: 0.7562
# Epoch 205/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0113e-05 - accuracy: 0.7858 - weighted_accuracy: 0.7639 - val_loss: 1.0674e-05 - val_accuracy: 0.7998 - val_weighted_accuracy: 0.7523
# Epoch 206/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0185e-05 - accuracy: 0.7844 - weighted_accuracy: 0.7623 - val_loss: 1.0552e-05 - val_accuracy: 0.7939 - val_weighted_accuracy: 0.7558
# Epoch 207/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 1.0150e-05 - accuracy: 0.7867 - weighted_accuracy: 0.7625 - val_loss: 1.0496e-05 - val_accuracy: 0.7883 - val_weighted_accuracy: 0.7551
# Epoch 208/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0153e-05 - accuracy: 0.7859 - weighted_accuracy: 0.7647 - val_loss: 1.0582e-05 - val_accuracy: 0.7949 - val_weighted_accuracy: 0.7535
# Epoch 209/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0133e-05 - accuracy: 0.7866 - weighted_accuracy: 0.7637 - val_loss: 1.0584e-05 - val_accuracy: 0.7994 - val_weighted_accuracy: 0.7549
# Epoch 210/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0101e-05 - accuracy: 0.7881 - weighted_accuracy: 0.7638 - val_loss: 1.0541e-05 - val_accuracy: 0.7711 - val_weighted_accuracy: 0.7534
# Epoch 211/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0155e-05 - accuracy: 0.7850 - weighted_accuracy: 0.7631 - val_loss: 1.0508e-05 - val_accuracy: 0.7911 - val_weighted_accuracy: 0.7553
# Epoch 212/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0114e-05 - accuracy: 0.7884 - weighted_accuracy: 0.7643 - val_loss: 1.0553e-05 - val_accuracy: 0.7650 - val_weighted_accuracy: 0.7493
# Epoch 213/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0123e-05 - accuracy: 0.7873 - weighted_accuracy: 0.7648 - val_loss: 1.0504e-05 - val_accuracy: 0.7799 - val_weighted_accuracy: 0.7541
# Epoch 214/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0110e-05 - accuracy: 0.7881 - weighted_accuracy: 0.7648 - val_loss: 1.0500e-05 - val_accuracy: 0.7744 - val_weighted_accuracy: 0.7530
# Epoch 215/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0104e-05 - accuracy: 0.7873 - weighted_accuracy: 0.7653 - val_loss: 1.0506e-05 - val_accuracy: 0.7800 - val_weighted_accuracy: 0.7537
# Epoch 216/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0145e-05 - accuracy: 0.7865 - weighted_accuracy: 0.7629 - val_loss: 1.0540e-05 - val_accuracy: 0.7863 - val_weighted_accuracy: 0.7542
# Epoch 217/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0075e-05 - accuracy: 0.7888 - weighted_accuracy: 0.7650 - val_loss: 1.0522e-05 - val_accuracy: 0.7776 - val_weighted_accuracy: 0.7531
# Epoch 218/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0125e-05 - accuracy: 0.7887 - weighted_accuracy: 0.7657 - val_loss: 1.0515e-05 - val_accuracy: 0.7780 - val_weighted_accuracy: 0.7547
# Epoch 219/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0125e-05 - accuracy: 0.7876 - weighted_accuracy: 0.7642 - val_loss: 1.0506e-05 - val_accuracy: 0.7775 - val_weighted_accuracy: 0.7553
# Epoch 220/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0112e-05 - accuracy: 0.7885 - weighted_accuracy: 0.7663 - val_loss: 1.0543e-05 - val_accuracy: 0.7802 - val_weighted_accuracy: 0.7517
# Epoch 221/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0096e-05 - accuracy: 0.7874 - weighted_accuracy: 0.7658 - val_loss: 1.0603e-05 - val_accuracy: 0.7979 - val_weighted_accuracy: 0.7537
# Epoch 222/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0111e-05 - accuracy: 0.7884 - weighted_accuracy: 0.7666 - val_loss: 1.0525e-05 - val_accuracy: 0.7724 - val_weighted_accuracy: 0.7519
# Epoch 223/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0086e-05 - accuracy: 0.7884 - weighted_accuracy: 0.7653 - val_loss: 1.0522e-05 - val_accuracy: 0.7925 - val_weighted_accuracy: 0.7557
# Epoch 224/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0136e-05 - accuracy: 0.7886 - weighted_accuracy: 0.7662 - val_loss: 1.0521e-05 - val_accuracy: 0.7872 - val_weighted_accuracy: 0.7555
# Epoch 225/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 1.0131e-05 - accuracy: 0.7872 - weighted_accuracy: 0.7638 - val_loss: 1.0539e-05 - val_accuracy: 0.7874 - val_weighted_accuracy: 0.7548
# Epoch 226/1000
# ...
# Epoch 926/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4149e-06 - accuracy: 0.7958 - weighted_accuracy: 0.7840 - val_loss: 1.0928e-05 - val_accuracy: 0.7630 - val_weighted_accuracy: 0.7429
# Epoch 927/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.4162e-06 - accuracy: 0.7955 - weighted_accuracy: 0.7845 - val_loss: 1.0912e-05 - val_accuracy: 0.7821 - val_weighted_accuracy: 0.7468
# Epoch 928/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3896e-06 - accuracy: 0.7948 - weighted_accuracy: 0.7834 - val_loss: 1.0901e-05 - val_accuracy: 0.7814 - val_weighted_accuracy: 0.7458
# Epoch 929/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3714e-06 - accuracy: 0.7946 - weighted_accuracy: 0.7820 - val_loss: 1.0883e-05 - val_accuracy: 0.7735 - val_weighted_accuracy: 0.7474
# Epoch 930/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4534e-06 - accuracy: 0.7955 - weighted_accuracy: 0.7814 - val_loss: 1.0850e-05 - val_accuracy: 0.7647 - val_weighted_accuracy: 0.7437
# Epoch 931/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4078e-06 - accuracy: 0.7920 - weighted_accuracy: 0.7817 - val_loss: 1.0919e-05 - val_accuracy: 0.7810 - val_weighted_accuracy: 0.7438
# Epoch 932/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4075e-06 - accuracy: 0.7947 - weighted_accuracy: 0.7819 - val_loss: 1.0921e-05 - val_accuracy: 0.7864 - val_weighted_accuracy: 0.7472
# Epoch 933/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3974e-06 - accuracy: 0.7945 - weighted_accuracy: 0.7828 - val_loss: 1.0895e-05 - val_accuracy: 0.7760 - val_weighted_accuracy: 0.7496
# Epoch 934/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4209e-06 - accuracy: 0.7963 - weighted_accuracy: 0.7838 - val_loss: 1.0983e-05 - val_accuracy: 0.7555 - val_weighted_accuracy: 0.7423
# Epoch 935/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4257e-06 - accuracy: 0.7933 - weighted_accuracy: 0.7819 - val_loss: 1.0905e-05 - val_accuracy: 0.7679 - val_weighted_accuracy: 0.7470
# Epoch 936/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3967e-06 - accuracy: 0.7943 - weighted_accuracy: 0.7818 - val_loss: 1.0934e-05 - val_accuracy: 0.7813 - val_weighted_accuracy: 0.7459
# Epoch 937/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4135e-06 - accuracy: 0.7957 - weighted_accuracy: 0.7831 - val_loss: 1.0877e-05 - val_accuracy: 0.7611 - val_weighted_accuracy: 0.7421
# Epoch 938/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4174e-06 - accuracy: 0.7937 - weighted_accuracy: 0.7824 - val_loss: 1.1095e-05 - val_accuracy: 0.7937 - val_weighted_accuracy: 0.7433
# Epoch 939/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4047e-06 - accuracy: 0.7962 - weighted_accuracy: 0.7830 - val_loss: 1.0894e-05 - val_accuracy: 0.7598 - val_weighted_accuracy: 0.7448
# Epoch 940/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3332e-06 - accuracy: 0.7958 - weighted_accuracy: 0.7825 - val_loss: 1.0984e-05 - val_accuracy: 0.7875 - val_weighted_accuracy: 0.7445
# Epoch 941/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3973e-06 - accuracy: 0.7967 - weighted_accuracy: 0.7826 - val_loss: 1.0890e-05 - val_accuracy: 0.7686 - val_weighted_accuracy: 0.7443
# Epoch 942/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3706e-06 - accuracy: 0.7964 - weighted_accuracy: 0.7851 - val_loss: 1.0941e-05 - val_accuracy: 0.7616 - val_weighted_accuracy: 0.7426
# Epoch 943/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.4261e-06 - accuracy: 0.7934 - weighted_accuracy: 0.7812 - val_loss: 1.0886e-05 - val_accuracy: 0.7822 - val_weighted_accuracy: 0.7468
# Epoch 944/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4299e-06 - accuracy: 0.7953 - weighted_accuracy: 0.7818 - val_loss: 1.0867e-05 - val_accuracy: 0.7716 - val_weighted_accuracy: 0.7472
# Epoch 945/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.3731e-06 - accuracy: 0.7943 - weighted_accuracy: 0.7828 - val_loss: 1.0898e-05 - val_accuracy: 0.7876 - val_weighted_accuracy: 0.7479
# Epoch 946/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3779e-06 - accuracy: 0.7969 - weighted_accuracy: 0.7838 - val_loss: 1.0924e-05 - val_accuracy: 0.7875 - val_weighted_accuracy: 0.7470
# Epoch 947/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.4030e-06 - accuracy: 0.7944 - weighted_accuracy: 0.7822 - val_loss: 1.0928e-05 - val_accuracy: 0.7821 - val_weighted_accuracy: 0.7460
# Epoch 948/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3791e-06 - accuracy: 0.7949 - weighted_accuracy: 0.7838 - val_loss: 1.0864e-05 - val_accuracy: 0.7637 - val_weighted_accuracy: 0.7409
# Epoch 949/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3991e-06 - accuracy: 0.7963 - weighted_accuracy: 0.7836 - val_loss: 1.0973e-05 - val_accuracy: 0.7461 - val_weighted_accuracy: 0.7393
# Epoch 950/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4240e-06 - accuracy: 0.7935 - weighted_accuracy: 0.7818 - val_loss: 1.0891e-05 - val_accuracy: 0.7645 - val_weighted_accuracy: 0.7444
# Epoch 951/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4217e-06 - accuracy: 0.7939 - weighted_accuracy: 0.7828 - val_loss: 1.0858e-05 - val_accuracy: 0.7822 - val_weighted_accuracy: 0.7487
# Epoch 952/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4130e-06 - accuracy: 0.7943 - weighted_accuracy: 0.7819 - val_loss: 1.0882e-05 - val_accuracy: 0.7738 - val_weighted_accuracy: 0.7442
# Epoch 953/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4085e-06 - accuracy: 0.7954 - weighted_accuracy: 0.7818 - val_loss: 1.0963e-05 - val_accuracy: 0.7857 - val_weighted_accuracy: 0.7457
# Epoch 954/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4035e-06 - accuracy: 0.7956 - weighted_accuracy: 0.7837 - val_loss: 1.0902e-05 - val_accuracy: 0.7776 - val_weighted_accuracy: 0.7453
# Epoch 955/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4296e-06 - accuracy: 0.7960 - weighted_accuracy: 0.7831 - val_loss: 1.0894e-05 - val_accuracy: 0.7609 - val_weighted_accuracy: 0.7413
# Epoch 956/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.4277e-06 - accuracy: 0.7933 - weighted_accuracy: 0.7832 - val_loss: 1.0971e-05 - val_accuracy: 0.7907 - val_weighted_accuracy: 0.7446
# Epoch 957/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3897e-06 - accuracy: 0.7948 - weighted_accuracy: 0.7841 - val_loss: 1.0902e-05 - val_accuracy: 0.7797 - val_weighted_accuracy: 0.7462
# Epoch 958/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3968e-06 - accuracy: 0.7962 - weighted_accuracy: 0.7827 - val_loss: 1.1058e-05 - val_accuracy: 0.7437 - val_weighted_accuracy: 0.7388
# Epoch 959/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4109e-06 - accuracy: 0.7929 - weighted_accuracy: 0.7823 - val_loss: 1.0886e-05 - val_accuracy: 0.7777 - val_weighted_accuracy: 0.7484
# Epoch 960/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.3921e-06 - accuracy: 0.7958 - weighted_accuracy: 0.7831 - val_loss: 1.1000e-05 - val_accuracy: 0.7857 - val_weighted_accuracy: 0.7418
# Epoch 961/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3840e-06 - accuracy: 0.7947 - weighted_accuracy: 0.7835 - val_loss: 1.1140e-05 - val_accuracy: 0.7961 - val_weighted_accuracy: 0.7441
# Epoch 962/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4576e-06 - accuracy: 0.7938 - weighted_accuracy: 0.7819 - val_loss: 1.0857e-05 - val_accuracy: 0.7808 - val_weighted_accuracy: 0.7466
# Epoch 963/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3895e-06 - accuracy: 0.7946 - weighted_accuracy: 0.7830 - val_loss: 1.0903e-05 - val_accuracy: 0.7859 - val_weighted_accuracy: 0.7456
# Epoch 964/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.4198e-06 - accuracy: 0.7949 - weighted_accuracy: 0.7827 - val_loss: 1.0929e-05 - val_accuracy: 0.7572 - val_weighted_accuracy: 0.7434
# Epoch 965/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3709e-06 - accuracy: 0.7955 - weighted_accuracy: 0.7821 - val_loss: 1.0900e-05 - val_accuracy: 0.7684 - val_weighted_accuracy: 0.7434
# Epoch 966/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3577e-06 - accuracy: 0.7957 - weighted_accuracy: 0.7843 - val_loss: 1.0921e-05 - val_accuracy: 0.7867 - val_weighted_accuracy: 0.7471
# Epoch 967/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.3705e-06 - accuracy: 0.7966 - weighted_accuracy: 0.7839 - val_loss: 1.0939e-05 - val_accuracy: 0.7873 - val_weighted_accuracy: 0.7490
# Epoch 968/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.3798e-06 - accuracy: 0.7957 - weighted_accuracy: 0.7831 - val_loss: 1.0878e-05 - val_accuracy: 0.7741 - val_weighted_accuracy: 0.7457
# Epoch 969/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4097e-06 - accuracy: 0.7959 - weighted_accuracy: 0.7825 - val_loss: 1.0930e-05 - val_accuracy: 0.7589 - val_weighted_accuracy: 0.7433
# Epoch 970/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3815e-06 - accuracy: 0.7958 - weighted_accuracy: 0.7828 - val_loss: 1.0925e-05 - val_accuracy: 0.7874 - val_weighted_accuracy: 0.7473
# Epoch 971/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3617e-06 - accuracy: 0.7967 - weighted_accuracy: 0.7852 - val_loss: 1.0987e-05 - val_accuracy: 0.7542 - val_weighted_accuracy: 0.7392
# Epoch 972/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3696e-06 - accuracy: 0.7941 - weighted_accuracy: 0.7840 - val_loss: 1.0876e-05 - val_accuracy: 0.7684 - val_weighted_accuracy: 0.7447
# Epoch 973/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.3578e-06 - accuracy: 0.7957 - weighted_accuracy: 0.7850 - val_loss: 1.0916e-05 - val_accuracy: 0.7879 - val_weighted_accuracy: 0.7472
# Epoch 974/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4184e-06 - accuracy: 0.7954 - weighted_accuracy: 0.7837 - val_loss: 1.0894e-05 - val_accuracy: 0.7687 - val_weighted_accuracy: 0.7434
# Epoch 975/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4365e-06 - accuracy: 0.7950 - weighted_accuracy: 0.7824 - val_loss: 1.0919e-05 - val_accuracy: 0.7634 - val_weighted_accuracy: 0.7424
# Epoch 976/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4547e-06 - accuracy: 0.7933 - weighted_accuracy: 0.7827 - val_loss: 1.0901e-05 - val_accuracy: 0.7635 - val_weighted_accuracy: 0.7435
# Epoch 977/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4159e-06 - accuracy: 0.7945 - weighted_accuracy: 0.7825 - val_loss: 1.0884e-05 - val_accuracy: 0.7825 - val_weighted_accuracy: 0.7480
# Epoch 978/1000
# 56/56 [==============================] - 4s 64ms/step - loss: 9.4369e-06 - accuracy: 0.7940 - weighted_accuracy: 0.7817 - val_loss: 1.0882e-05 - val_accuracy: 0.7660 - val_weighted_accuracy: 0.7449
# Epoch 979/1000
# 56/56 [==============================] - 4s 63ms/step - loss: 9.4404e-06 - accuracy: 0.7944 - weighted_accuracy: 0.7845 - val_loss: 1.0864e-05 - val_accuracy: 0.7782 - val_weighted_accuracy: 0.7471
# Epoch 980/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4134e-06 - accuracy: 0.7940 - weighted_accuracy: 0.7830 - val_loss: 1.0870e-05 - val_accuracy: 0.7747 - val_weighted_accuracy: 0.7469
# Epoch 981/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3880e-06 - accuracy: 0.7954 - weighted_accuracy: 0.7830 - val_loss: 1.0946e-05 - val_accuracy: 0.7618 - val_weighted_accuracy: 0.7435
# Epoch 982/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4079e-06 - accuracy: 0.7957 - weighted_accuracy: 0.7829 - val_loss: 1.0940e-05 - val_accuracy: 0.7585 - val_weighted_accuracy: 0.7422
# Epoch 983/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4283e-06 - accuracy: 0.7944 - weighted_accuracy: 0.7826 - val_loss: 1.0880e-05 - val_accuracy: 0.7793 - val_weighted_accuracy: 0.7449
# Epoch 984/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4089e-06 - accuracy: 0.7957 - weighted_accuracy: 0.7839 - val_loss: 1.0863e-05 - val_accuracy: 0.7688 - val_weighted_accuracy: 0.7464
# Epoch 985/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4385e-06 - accuracy: 0.7952 - weighted_accuracy: 0.7833 - val_loss: 1.0870e-05 - val_accuracy: 0.7653 - val_weighted_accuracy: 0.7460
# Epoch 986/1000
# 56/56 [==============================] - 4s 64ms/step - loss: 9.4000e-06 - accuracy: 0.7960 - weighted_accuracy: 0.7849 - val_loss: 1.0904e-05 - val_accuracy: 0.7672 - val_weighted_accuracy: 0.7450
# Epoch 987/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3610e-06 - accuracy: 0.7961 - weighted_accuracy: 0.7846 - val_loss: 1.0886e-05 - val_accuracy: 0.7822 - val_weighted_accuracy: 0.7473
# Epoch 988/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3864e-06 - accuracy: 0.7964 - weighted_accuracy: 0.7840 - val_loss: 1.0848e-05 - val_accuracy: 0.7677 - val_weighted_accuracy: 0.7438
# Epoch 989/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3828e-06 - accuracy: 0.7963 - weighted_accuracy: 0.7837 - val_loss: 1.0920e-05 - val_accuracy: 0.7712 - val_weighted_accuracy: 0.7449
# Epoch 990/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3713e-06 - accuracy: 0.7962 - weighted_accuracy: 0.7843 - val_loss: 1.0853e-05 - val_accuracy: 0.7805 - val_weighted_accuracy: 0.7468
# Epoch 991/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4061e-06 - accuracy: 0.7944 - weighted_accuracy: 0.7831 - val_loss: 1.1074e-05 - val_accuracy: 0.7931 - val_weighted_accuracy: 0.7443
# Epoch 992/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4013e-06 - accuracy: 0.7964 - weighted_accuracy: 0.7834 - val_loss: 1.0879e-05 - val_accuracy: 0.7808 - val_weighted_accuracy: 0.7447
# Epoch 993/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3999e-06 - accuracy: 0.7964 - weighted_accuracy: 0.7846 - val_loss: 1.0870e-05 - val_accuracy: 0.7784 - val_weighted_accuracy: 0.7476
# Epoch 994/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3742e-06 - accuracy: 0.7956 - weighted_accuracy: 0.7835 - val_loss: 1.0928e-05 - val_accuracy: 0.7671 - val_weighted_accuracy: 0.7463
# Epoch 995/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3567e-06 - accuracy: 0.7972 - weighted_accuracy: 0.7857 - val_loss: 1.0892e-05 - val_accuracy: 0.7741 - val_weighted_accuracy: 0.7444
# Epoch 996/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.3737e-06 - accuracy: 0.7965 - weighted_accuracy: 0.7842 - val_loss: 1.0871e-05 - val_accuracy: 0.7684 - val_weighted_accuracy: 0.7454
# Epoch 997/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.3790e-06 - accuracy: 0.7934 - weighted_accuracy: 0.7827 - val_loss: 1.0908e-05 - val_accuracy: 0.7826 - val_weighted_accuracy: 0.7441
# Epoch 998/1000
# 56/56 [==============================] - 3s 60ms/step - loss: 9.3634e-06 - accuracy: 0.7959 - weighted_accuracy: 0.7844 - val_loss: 1.1151e-05 - val_accuracy: 0.7969 - val_weighted_accuracy: 0.7436
# Epoch 999/1000
# 56/56 [==============================] - 3s 62ms/step - loss: 9.4071e-06 - accuracy: 0.7952 - weighted_accuracy: 0.7825 - val_loss: 1.1006e-05 - val_accuracy: 0.7508 - val_weighted_accuracy: 0.7401
# Epoch 1000/1000
# 56/56 [==============================] - 3s 61ms/step - loss: 9.4403e-06 - accuracy: 0.7954 - weighted_accuracy: 0.7845 - val_loss: 1.0980e-05 - val_accuracy: 0.7577 - val_weighted_accuracy: 0.7432

# %% [markdown]
# ## Plot performance
# Here, we plot the history of the training and the performance in a ROC curve

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(15,10))

# plot loss vs epoch
ax = plt.subplot(2, 2, 1)
ax.plot(history.history['loss'], label='loss')
ax.plot(history.history['val_loss'], label='val_loss')
#ax.set_ylim([0, 1])
ax.legend(loc="upper right")
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')

# plot accuracy vs epoch
ax = plt.subplot(2, 2, 2)
ax.plot(history.history['accuracy'], label='acc')
ax.plot(history.history['val_accuracy'], label='val_acc')
ax.set_ylim([0, 1.0])
ax.legend(loc="upper left")
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')

# Plot ROC
Y_predict = model.predict(X_test)
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
roc_auc = auc(fpr, tpr)
ax = plt.subplot(2, 2, 3)
ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
ax.set_xlim([0, 1.0])
ax.set_ylim([0, 1.0])
ax.set_xlabel('False Positive Rate(FPR)')
ax.set_ylabel('True Positive Rate(TPR)')
ax.set_title('Receiver Operating Curve(ROC)')
ax.legend(loc="lower right")

# Plot DNN output 
df_sig  = df['sig'].filter(NN_VARS)
df_bkg  = df['bkg'].filter(NN_VARS)

X_sig  = np.asarray( df_sig.values ).astype(np.float32)
X_bkg  = np.asarray( df_bkg.values ).astype(np.float32)

Y_sig = model.predict(X_sig)
Y_bkg = model.predict(X_bkg)

ax = plt.subplot(2, 2, 4)
X = np.linspace(0.0, 1.0, 100)
hist_sig = ax.hist(Y_sig, bins=X, label='sig',histtype='step')
hist_bkg = ax.hist(Y_bkg, bins=X, label='bkg',histtype='step',)

#ax.hist(Y_train_val, bins=X, label='bkg',histtype='step')

ax.set_xlabel('DNN Output')
ax.legend(prop={'size': 10})
plt.show()

# %% [markdown]
# # Plot  $m_{jj}$, $\eta_{j}$ and $m_{4l}$  for NN output > cut to show that the NN did learned the physics !

# %%
import matplotlib.pyplot as plt

# Define the data frame of high level variables and NN output
data = df_all.filter(NN_VARS)
X_all   = np.asarray( data.values ).astype(np.float32)
Y_all = model.predict(X_all)

# Add the NN prediction array ( Y_all ) column to the complete dataframe
df_all['NNoutput'] = Y_all

# Selects events with NNoutput > cut
cut = 0.5 
df_sel   = df_all[(df_all['NNoutput'] >= cut)]
df_TP    = df_all[(df_all['NNoutput'] >= cut) & (df_all['isSignal'] == 1)]
df_unsel = df_all[(df_all['NNoutput'] < cut)]
df_TN    = df_all[(df_all['NNoutput'] < cut) & (df_all['isSignal'] == 0)]

TP = len(df_TP)
FP = len(df_sel) - TP
TN = len(df_TN)
FN = len(df_unsel) - TN

truepositiverate = float(TP)/(TP+FN)
fakepositiverate = float(FP)/(FP+FN)
print(truepositiverate)
print(fakepositiverate)
    
# Plot high level variables for signal, background and NN selected events 
plt.style.use('default') # It's ugly otherwise
plt.figure(figsize=(16, 16),dpi=100)

plt.subplot(2, 2, 1)
plt.xlabel('deltajj')
X = np.linspace(0.0,10.,100)
df_all['f_deltajj'][(df_all['isSignal'] == 0)].plot.hist(bins=X, label='bkg',histtype='step', density=1)
df_all['f_deltajj'][(df_all['isSignal'] == 1)].plot.hist(bins=X, label='signal',histtype='step', density=1)
df_sel['f_deltajj'].plot.hist(bins=X, label='NN',histtype='step', density=1)
plt.legend(loc='upper right')
plt.xlim(0,10)

# Plot  dijets mass for signal, background and NN selected events 
plt.subplot(2, 2, 2)
plt.xlabel('massjj')
X = np.linspace(0.0,1000.,100)
df_all['f_massjj'][(df_all['isSignal'] == 0)].plot.hist(bins=X, label='bkg',histtype='step', density=1)
df_all['f_massjj'][(df_all['isSignal'] == 1)].plot.hist(bins=X, label='signal',histtype='step', density=1)
df_sel['f_massjj'].plot.hist(bins=X, label='NN',histtype='step', density=1)
plt.legend(loc='upper right')
plt.xlim(0,1000)


# Plot Jet1 eta for signal, background and NN selected events 
plt.subplot(2, 2, 3)
plt.xlabel('Jet1 eta')
X = np.linspace(-5.,5.,100)
df_all['f_jet1_eta'][(df_all['isSignal'] == 0)].plot.hist(bins=X, label='bkg',histtype='step', density=1)
df_all['f_jet1_eta'][(df_all['isSignal'] == 1)].plot.hist(bins=X, label='signal',histtype='step', density=1)
df_sel['f_jet1_eta'].plot.hist(bins=X, label='NN',histtype='step', density=1)
plt.legend(loc='upper right')
plt.xlim(-5,5)

# Plot Jet2 eta for signal, background and NN selected events 
plt.subplot(2, 2, 4)
plt.xlabel('Jet2 eta')
X = np.linspace(-5.,5.,100)
df_all['f_jet2_eta'][(df_all['isSignal'] == 0)].plot.hist(bins=X, label='bkg',histtype='step', density=1)
df_all['f_jet2_eta'][(df_all['isSignal'] == 1)].plot.hist(bins=X, label='signal',histtype='step', density=1)
df_sel['f_jet2_eta'].plot.hist(bins=X, label='NN',histtype='step', density=1)
plt.legend(loc='upper right')
plt.xlim(-5,5)
# Out:
# 0.7694884813318136
# 0.7068564149866035
# (-5.0, 5.0)
