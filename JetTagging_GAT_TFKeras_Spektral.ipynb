# %% [markdown]
# <a href="https://colab.research.google.com/github/sznajder/Notebooks/blob/master/JetTagging_GAT_TFKeras_Spektral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Attention Network(GAT)
#  for Jet-Images
# Author: Andre Sznajder

# %%
#!fusermount -u drive
! pip install einops
#! pip install spektral
! pip install --upgrade git+https://github.com/danielegrattarola/spektral.git
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Collecting git+https://github.com/danielegrattarola/spektral.git
#   Cloning https://github.com/danielegrattarola/spektral.git to /tmp/pip-req-build-9xkjv1ze
#   Running command git clone -q https://github.com/danielegrattarola/spektral.git /tmp/pip-req-build-9xkjv1ze
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (1.0.1)
# Requirement already satisfied, skipping upgrade: lxml in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (4.2.6)
# Requirement already satisfied, skipping upgrade: networkx in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (2.5)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (1.19.5)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (1.1.5)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (2.23.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (1.4.1)
# Requirement already satisfied, skipping upgrade: tensorflow>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (2.4.1)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from spektral==1.0.5) (4.41.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx->spektral==1.0.5) (4.4.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->spektral==1.0.5) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->spektral==1.0.5) (2018.9)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->spektral==1.0.5) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->spektral==1.0.5) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->spektral==1.0.5) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->spektral==1.0.5) (2.10)
# Requirement already satisfied, skipping upgrade: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (1.1.2)
# Requirement already satisfied, skipping upgrade: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (0.2.0)
# Requirement already satisfied, skipping upgrade: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (2.4.1)
# Requirement already satisfied, skipping upgrade: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (3.3.0)
# Requirement already satisfied, skipping upgrade: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (1.6.3)
# Requirement already satisfied, skipping upgrade: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (0.36.2)
# Requirement already satisfied, skipping upgrade: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (1.15.0)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (0.3.3)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (2.4.0)
# Requirement already satisfied, skipping upgrade: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (1.32.0)
# Requirement already satisfied, skipping upgrade: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (2.10.0)
# Requirement already satisfied, skipping upgrade: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (1.1.0)
# Requirement already satisfied, skipping upgrade: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (1.12)
# Requirement already satisfied, skipping upgrade: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (0.10.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (3.12.4)
# Requirement already satisfied, skipping upgrade: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral==1.0.5) (1.12.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (1.27.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (3.3.4)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (1.0.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (0.4.2)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (1.8.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (54.0.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (4.7.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (4.2.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (0.2.8)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (3.7.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (0.4.8)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (3.4.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.1.0->spektral==1.0.5) (3.1.0)
# Building wheels for collected packages: spektral
#   Building wheel for spektral (setup.py) ... done
#   Created wheel for spektral: filename=spektral-1.0.5-cp37-none-any.whl size=112358 sha256=af6e0c8829bf0afbbbb28bbcd469c2a3e41ba47d7ee0fd92f15780af90c7f4d8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-auwhrbh9/wheels/83/60/1f/a45c48d66dbbee6c98123fd345a7212bdc5b79449095a985da
# Successfully built spektral
# Installing collected packages: spektral
#   Found existing installation: spektral 1.0.5
#     Uninstalling spektral-1.0.5:
#       Successfully uninstalled spektral-1.0.5
# Successfully installed spektral-1.0.5

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
data_dir = '/content/gdrive/My Drive/Colab Notebooks/Data/'

from sklearn.model_selection import train_test_split
from sklearn.neighbors import kneighbors_graph
import h5py
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from math import *

import scipy.sparse as sp
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import Input, Activation, Dense, Dropout, Flatten , BatchNormalization
from tensorflow.keras import utils

from spektral.layers.ops import sp_matrix_to_sp_tensor
from spektral.layers import GCNConv, EdgeConv, ECCConv, GATConv, GlobalSumPool, GlobalAvgPool 
from spektral.data import Dataset, DisjointLoader, Graph
from spektral.data import SingleLoader, DisjointLoader, BatchLoader, MixedLoader, PackedBatchLoader
from spektral.data.loaders import SingleLoader
from spektral.transforms.normalize_adj import NormalizeAdj
from spektral.transforms import AdjToSpTensor, LayerPreprocess
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load numpy arrays
# Here, we load the numpy arrays containing the 4D tensors of "jet-images" (see https://arxiv.org/pdf/1511.05190.pdf)

# %%
h5f = h5py.File(data_dir+"jet_images.h5", "r")

jet_images_dict = {}
jet_images_dict['QCD'] = h5f['QCD'][()]
jet_images_dict['TT'] = h5f['TT'][()]

h5f.close()

# %%
# 4D tensor (tensorflow backend)
# 1st dim is jet index
# 2nd dim is eta bin
# 3rd dim is phi bin
# 4th dim is pt value (or rgb values, etc.)
print(jet_images_dict['QCD'].ndim)
njet_qcd = jet_images_dict['QCD'].shape[0]
njet_tt = jet_images_dict['TT'].shape[0]
neta = jet_images_dict['TT'].shape[1]
nphi = jet_images_dict['TT'].shape[2]
npt = jet_images_dict['TT'].shape[3]

ncells = neta*nphi
print('Number of QCD jets=',njet_qcd)
print('Number of TT jets=',njet_tt)
print('Number of Phi bins=',nphi)
print('Number of Eta bins=',neta)
print('Number of Pt bins=',npt)
# Out:
# 4
# Number of QCD jets= 3305
# Number of TT jets= 1821
# Number of Phi bins= 30
# Number of Eta bins= 30
# Number of Pt bins= 1

# %% [markdown]
# ## Plotting jet-images
# Let's plot some jet-images (individual jets and averaged over all jets)
#
# **Question 1:**  Try to plot the average W and QCD jet-images.

# %%
# %matplotlib inline
plt.style.use('default')

# plot one W jet
i = 7
plt.figure('W') 
plt.imshow(jet_images_dict['TT'][i,:,:,0].T, norm=mpl.colors.LogNorm(), origin='lower', interpolation='none')
cbar = plt.colorbar()
cbar.set_label('pT')
plt.xlabel('ieta')
plt.ylabel('iphi')
plt.show()

# plot average W jet

# %%
# plot one QCD jet
i = 7
plt.figure() 
plt.imshow(jet_images_dict['QCD'][i,:,:,0].T, norm=mpl.colors.LogNorm(), origin='lower', interpolation='none')
cbar = plt.colorbar()
cbar.set_label('pT')
plt.xlabel('ieta')
plt.ylabel('iphi')
plt.show()

# plot average QCD jet

# %% [markdown]
# ## Create Graphs and defines class MyDataset as defined in:
#
# https://github.com/danielegrattarola/spektral/blob/master/examples/graph_prediction/custom_dataset.py

# %% [markdown]
# #===============================================
#
# # Based on SPEKTRAL library ( https://graphneural.network )
#
# Using example from:
# https://github.com/danielegrattarola/spektral/blob/master/examples/other/graph_signal_classification_mnist.py
#
#
# #===============================================

# %%
class MyDataset(Dataset):
    """
    A dataset of Jet Image graphs.
    """

    def __init__(self, n_samples, jet_images_dict, **kwargs):
      self.n_samples = n_samples
      self.jet_images_dict = jet_images_dict
      self.n_features = 3
      self.n_edgefeatures = 1
      self.n_out = 1
      super().__init__(**kwargs)


    def read(self):

      # Create Graphs from jet images with the following format
      #
      #  Adjacent matrix:  A[batch_size, num_nodes, num_nodes] (should be normalized in advance)
      #  Features matrix:  X[batch_size, num_nodes, num_features]
      #       

      ngraphs = len(self.jet_images_dict) # Number of graphs ( number of jets )
      
      # Concatenate signal and backgrounds data
      njet_qcd = self.jet_images_dict['QCD'].shape[0]
      njet_tt =  self.jet_images_dict['TT'].shape[0]
      jet_images = np.concatenate( [ self.jet_images_dict['TT'], self.jet_images_dict['QCD'] ] )
      jet_labels = np.concatenate( [ np.ones(njet_tt), np.zeros(njet_qcd) ] )

      nnodes  = ncells   # Number of graph nodes   ( number of cells/towers in a jet )
      ptmin   = 0.1      # Treshold for energy deposit 

      # Loop over jets to create a Graph
      Graphs=[]
      ng = 0
#      Y=np.zeros(1)
      for jet , label in zip(jet_images,jet_labels): 
   
        # Check if reached max # of requested graphs 
        if (ng > self.n_samples): break
        ng += 1

        # Graph nodes are the jet calo cells with features ( ieta , iphi , pt ) above treshold PTMIN 
        cells = [ [ ieta, iphi , jet[ieta,iphi,0] ] for ieta in range(neta) for iphi in range(nphi) if jet[ieta,iphi,0] > ptmin ]
        if len(cells)==0 : continue # skip jet processing if it contains no cells above treshold 
        X = np.array(cells) # transform the list of node features into a ndarray
        Y = label
        
        # Create an Adjacency matrix using KNN algorithm
        k=4
        A = kneighbors_graph(X, k)
 
        # Convert sparse A to a dense A format
#        A = A.toarray() 
        A = A.todense() 

        if np.all(A==0) : 
          print('SHIT !!! -------------------------------------- > A is NULL')
          continue 

#        print('Shape A=',A.shape)
#        print('A=',A)

#        print('Shape X=',X.shape)
#        print('Shape A=',A.shape)
#        print('Shape E=',E.shape)
#        print(' ')
#        print(' ')

        # Add graph to list
        G = Graph(x=X,a=A,y=Y)
        Graphs.append(G)

      # Number of generated Graphs
      print('Number of generated Graphs=',ng)

      # Return Graphs list              
      return Graphs

####################################################

#print('len jet_images_dict=',len(jet_images_dict))
#dataset = MyDataset( 5000, jet_images_dict, transforms=NormalizeAdj() )
dataset = MyDataset(5000,jet_images_dict)

# Dataset Parameters
n_nodes_max = max(g.n_nodes for g in dataset)
n_nodes_min = min(g.n_nodes for g in dataset)
n_out = dataset.n_out  # Dimension of the target
n_node_features = dataset.n_features  # Dimension of the target
n_edge_features = dataset.n_edgefeatures  # Dimension of the target

print('Maximum number of nodes=',n_nodes_max)
print('Minimum number of nodes=',n_nodes_min)
print('Dimension of node features=', n_node_features)
print('Dimension of edge features=', n_edge_features)
print('Dimension of NN output target=', n_out)
# Out:
# Number of generated Graphs= 5001
# Maximum number of nodes= 87
# Minimum number of nodes= 7
# Dimension of node features= 3
# Dimension of edge features= 1
# Dimension of NN output target= 1

# %% [markdown]
# ## Split data into testing and training dataset and Create a dataset Loader
#
# We will split the data into two parts (one for training+validation and one for testing) and use early stoppping regularization.
#
# Unlike regular data ( images or sequences ) graphs can have a variable size and we can fit them into tensors of pre-defined shape. If a graph has 10 nodes and another one has 4, we have to keep them that way.
#
# This means that iterating over a dataset in mini-batches is not trivial and we cannot simply use the model.fit() method of Keras as-is.
#
# We have to use a data Loader, which iterate over a graph dataset to create mini-batches. They hide a lot of the complexity behind the process, so that you don't need to think about it.
#
# You only need to specify the Data Mode. Each loader has a load() method that when called will return a data generator that Keras can process.
#
# Since we're doing graph-level classification, we can use a BatchLoader

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Choose training parameters 
n_epochs=100
n_batch= 32
print('Number of Training Epochs=',n_epochs)
print('Size of Training Batches=',n_batch)

# Number of graphs 
ngraphs = len(dataset)
print('Number of Graphs in dataset=',ngraphs)

# Create an indices array containing random permutations of graph indices
idxs = np.random.permutation(ngraphs)

# Split indices array into train, validation and test indices ( [:split_va] , [split_va,split_te] , [split_te:] )
split_va , split_te = int(0.8 * ngraphs) , int(0.9 * ngraphs)
idx_tr, idx_va, idx_te = np.split(idxs, [split_va, split_te]) 

# Define the sub-datasets based on their indices
dataset_tr = dataset[idx_tr]
dataset_va = dataset[idx_va]
dataset_te = dataset[idx_te]

# Create the Spektral data loader generator ( Data Modes: Single , Disjoint , Batch , Mixed or Packed )

loader_tr = BatchLoader(dataset_tr, batch_size=n_batch, epochs=n_epochs)
loader_va = BatchLoader(dataset_va, batch_size=n_batch)
loader_te = BatchLoader(dataset_te, batch_size=1, epochs=1)


#loader_tr = DisjointLoader(dataset_tr, batch_size=n_batch, epochs=n_epochs)
#loader_va = DisjointLoader(dataset_va, batch_size=n_batch)
#loader_te = DisjointLoader(dataset_te, batch_size=n_batch, epochs=1)

# Mixed mode: it's not possible to use loader.load() to train a model !!!  
#loader_tr = MixedLoader(dataset_tr, batch_size=n_batch, epochs=n_epochs)
#loader_va = MixedLoader(dataset_va, batch_size=n_batch)
#loader_te = MixedLoader(dataset_te, batch_size=n_batch, epochs=1)

#loader_tr = PackedBatchLoader(dataset_tr, batch_size=n_batch, epochs=n_epochs)
#loader_va = PackedBatchLoader(dataset_va, batch_size=n_batch)
#loader_te = PackedBatchLoader(dataset_te, batch_size=n_batch, epochs=1)

#inputs, target = loader_tr.__next__()

# Print train data
#X = [ g.x for g in dataset_tr ]
#A = [ (g.a).toarray() for g in dataset_tr ]
#A = [ (g.a) for g in dataset_tr ]
#E = [ (g.e) for g in dataset_tr ]
#Y = [ g.y for g in dataset_tr ]
#
#print('  ')
#print('  ')
#print('X=',X)
#print('A=',A)
#print('Y=',Y)
# Out:
# Number of Training Epochs= 100
# Size of Training Batches= 32
# Number of Graphs in dataset= 5001

# %% [markdown]
# ## Define our GAT model ( SPEKTRAL library )

# %%
# Define DEGCN network with two layers , a pooling layer and a two final dense layers for classification
F = dataset.n_node_features  # Dimension of node features
n_out = dataset.n_labels  # Dimension of the target

# Instantiate Tensorflow input tensors in Batch mode 
X = Input(shape=(None,F), name="X")
A = Input(shape=(None,None), name="A")  # GAT expects A in dense format when using batch mode !!!

# GAT Model ( Graph input ) 
#H = Dropout(0.2)(X)
#H = GATConv(F, activation="relu", attn_heads=F, concat_heads=True, dropout_rate=0.2)([H,A])
#H = Dropout(0.2)(H)
#H = GATConv(F, activation="softmax", attn_heads=1, concat_heads=True, dropout_rate=0.2)([H,A])
#H = BatchNormalization()(H)
#H = tf.reshape(H, [n_batch,n_nodes_max*n_node_features])
#H = Flatten()(H)

H = GATConv(F, activation="relu", attn_heads=F*10, concat_heads=True)([X,A])
H = GATConv(F, activation="softmax", attn_heads=F*10, concat_heads=True)([H,A])
print('H shape=',H.shape)
H = GlobalSumPool()(H)
print('H flattened shape=',H.shape)
H = Dense(int(n_nodes_max*F*10), activation="relu")(H)
O = Dense(1, activation="sigmoid") (H)



# Build the GATConv model
gatn = Model(inputs=[X,A], outputs=O)

# Define the optimizer ( minimization algorithm )
#opt = SGD(lr=0.01,decay=1e-6)
#opt = Adam(lr=0.001)
opt = Adam()


# Compile the model
#gatn.compile(optimizer=opt, loss="binary_crossentropy", weighted_metrics=["accuracy"])
gatn.compile(optimizer=opt, loss="binary_crossentropy", metrics=["accuracy"])

# print the model summary
gatn.summary()
# Out:
# H shape= (None, None, 90)
# H flattened shape= (None, 90)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# X (InputLayer)                  [(None, None, 3)]    0
# __________________________________________________________________________________________________
# A (InputLayer)                  [(None, None, None)] 0
# __________________________________________________________________________________________________
# gat_conv (GATConv)              (None, None, 90)     540         X[0][0]
#                                                                  A[0][0]
# __________________________________________________________________________________________________
# gat_conv_1 (GATConv)            (None, None, 90)     8370        gat_conv[0][0]
#                                                                  A[0][0]
# __________________________________________________________________________________________________
# global_sum_pool (GlobalSumPool) (None, 90)           0           gat_conv_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2610)         237510      global_sum_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2611        dense[0][0]
# ==================================================================================================
# Total params: 249,031
# Trainable params: 249,031
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train and Evaluate the classifier

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# early stopping callback
#
es = EarlyStopping(monitor='val_loss', patience=10)
#es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# model checkpoint callback ( this saves our model architecture + parameters into gcn_spektral_model.h5 )
mc = ModelCheckpoint('gcn_spektral_model.h5', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto',save_freq=1)


# Train classifier
history = gatn.fit( loader_tr.load(),
                   steps_per_epoch=loader_tr.steps_per_epoch,
                   epochs=n_epochs,
                   validation_data=loader_va,
                   validation_steps=loader_va.steps_per_epoch)
#                   callbacks=[es] )


# Evaluate classifier on test data
print("Testing model")
test_loss, test_accuracy = gatn.evaluate(loader_te.load(), steps=loader_te.steps_per_epoch)
print("Done. Test loss: {}. Test acc: {}".format(test_loss , test_accuracy))

#Y_prediction = gatn.predict([X_test,A_test] , batch_size=len(X_test))
# Out:
# Epoch 1/100
# 125/125 [==============================] - 3s 14ms/step - loss: 0.6599 - accuracy: 0.6414 - val_loss: 0.5649 - val_accuracy: 0.7200
# Epoch 2/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4760 - accuracy: 0.7756 - val_loss: 0.4401 - val_accuracy: 0.8020
# Epoch 3/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4273 - accuracy: 0.8059 - val_loss: 0.4029 - val_accuracy: 0.8200
# Epoch 4/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4277 - accuracy: 0.7965 - val_loss: 0.4050 - val_accuracy: 0.8160
# Epoch 5/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4163 - accuracy: 0.8119 - val_loss: 0.3500 - val_accuracy: 0.8480
# Epoch 6/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3827 - accuracy: 0.8333 - val_loss: 0.3449 - val_accuracy: 0.8460
# Epoch 7/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3450 - accuracy: 0.8507 - val_loss: 0.2967 - val_accuracy: 0.8620
# Epoch 8/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3530 - accuracy: 0.8564 - val_loss: 0.3426 - val_accuracy: 0.8480
# Epoch 9/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3294 - accuracy: 0.8545 - val_loss: 0.2862 - val_accuracy: 0.8900
# Epoch 10/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3216 - accuracy: 0.8636 - val_loss: 0.3324 - val_accuracy: 0.8400
# Epoch 11/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3132 - accuracy: 0.8702 - val_loss: 0.2577 - val_accuracy: 0.8860
# Epoch 12/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2984 - accuracy: 0.8793 - val_loss: 0.2825 - val_accuracy: 0.8820
# Epoch 13/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3139 - accuracy: 0.8667 - val_loss: 0.3178 - val_accuracy: 0.8740
# Epoch 14/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3271 - accuracy: 0.8673 - val_loss: 0.2632 - val_accuracy: 0.8980
# Epoch 15/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2968 - accuracy: 0.8837 - val_loss: 0.3531 - val_accuracy: 0.8700
# Epoch 16/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3378 - accuracy: 0.8562 - val_loss: 0.2601 - val_accuracy: 0.8840
# Epoch 17/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3052 - accuracy: 0.8750 - val_loss: 0.2625 - val_accuracy: 0.9000
# Epoch 18/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3068 - accuracy: 0.8725 - val_loss: 0.2813 - val_accuracy: 0.8940
# Epoch 19/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2939 - accuracy: 0.8864 - val_loss: 0.3112 - val_accuracy: 0.8800
# Epoch 20/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2791 - accuracy: 0.8945 - val_loss: 0.2566 - val_accuracy: 0.9040
# Epoch 21/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2921 - accuracy: 0.8870 - val_loss: 0.2906 - val_accuracy: 0.8740
# Epoch 22/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2881 - accuracy: 0.8827 - val_loss: 0.2217 - val_accuracy: 0.9140
# Epoch 23/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2895 - accuracy: 0.8873 - val_loss: 0.3146 - val_accuracy: 0.8560
# Epoch 24/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2811 - accuracy: 0.8869 - val_loss: 0.2605 - val_accuracy: 0.9000
# Epoch 25/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2895 - accuracy: 0.8863 - val_loss: 0.2989 - val_accuracy: 0.8840
# Epoch 26/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2746 - accuracy: 0.8911 - val_loss: 0.2711 - val_accuracy: 0.8900
# Epoch 27/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2580 - accuracy: 0.9035 - val_loss: 0.2904 - val_accuracy: 0.8720
# Epoch 28/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2858 - accuracy: 0.8849 - val_loss: 0.3102 - val_accuracy: 0.8640
# Epoch 29/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2988 - accuracy: 0.8787 - val_loss: 0.2437 - val_accuracy: 0.9060
# Epoch 30/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2786 - accuracy: 0.8874 - val_loss: 0.2531 - val_accuracy: 0.9080
# Epoch 31/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2606 - accuracy: 0.8937 - val_loss: 0.2689 - val_accuracy: 0.8840
# Epoch 32/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2968 - accuracy: 0.8784 - val_loss: 0.2582 - val_accuracy: 0.8960
# Epoch 33/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2779 - accuracy: 0.8912 - val_loss: 0.2518 - val_accuracy: 0.8900
# Epoch 34/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2648 - accuracy: 0.8990 - val_loss: 0.2599 - val_accuracy: 0.8920
# Epoch 35/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2907 - accuracy: 0.8771 - val_loss: 0.3598 - val_accuracy: 0.8520
# Epoch 36/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2873 - accuracy: 0.8812 - val_loss: 0.2636 - val_accuracy: 0.9000
# Epoch 37/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2817 - accuracy: 0.8880 - val_loss: 0.2481 - val_accuracy: 0.8900
# Epoch 38/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2680 - accuracy: 0.8933 - val_loss: 0.2585 - val_accuracy: 0.9000
# Epoch 39/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2820 - accuracy: 0.8887 - val_loss: 0.2618 - val_accuracy: 0.9000
# Epoch 40/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2828 - accuracy: 0.8837 - val_loss: 0.2421 - val_accuracy: 0.8860
# Epoch 41/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2589 - accuracy: 0.9059 - val_loss: 0.2424 - val_accuracy: 0.9160
# Epoch 42/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2724 - accuracy: 0.8890 - val_loss: 0.2317 - val_accuracy: 0.9100
# Epoch 43/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2663 - accuracy: 0.8961 - val_loss: 0.2385 - val_accuracy: 0.9220
# Epoch 44/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2676 - accuracy: 0.9005 - val_loss: 0.2885 - val_accuracy: 0.8760
# Epoch 45/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2712 - accuracy: 0.8984 - val_loss: 0.2564 - val_accuracy: 0.8900
# Epoch 46/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2648 - accuracy: 0.8943 - val_loss: 0.2444 - val_accuracy: 0.9080
# Epoch 47/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2662 - accuracy: 0.8962 - val_loss: 0.2721 - val_accuracy: 0.8880
# Epoch 48/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2747 - accuracy: 0.8926 - val_loss: 0.3009 - val_accuracy: 0.8800
# Epoch 49/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2675 - accuracy: 0.8879 - val_loss: 0.2425 - val_accuracy: 0.9080
# Epoch 50/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2540 - accuracy: 0.9044 - val_loss: 0.2450 - val_accuracy: 0.9040
# Epoch 51/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2541 - accuracy: 0.8927 - val_loss: 0.2500 - val_accuracy: 0.9100
# Epoch 52/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2676 - accuracy: 0.8978 - val_loss: 0.2731 - val_accuracy: 0.8840
# Epoch 53/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2554 - accuracy: 0.8982 - val_loss: 0.2570 - val_accuracy: 0.8980
# Epoch 54/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2537 - accuracy: 0.9031 - val_loss: 0.2583 - val_accuracy: 0.8940
# Epoch 55/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2859 - accuracy: 0.8857 - val_loss: 0.2374 - val_accuracy: 0.8960
# Epoch 56/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2764 - accuracy: 0.8902 - val_loss: 0.2545 - val_accuracy: 0.9000
# Epoch 57/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2613 - accuracy: 0.8924 - val_loss: 0.2341 - val_accuracy: 0.9120
# Epoch 58/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2660 - accuracy: 0.8947 - val_loss: 0.2373 - val_accuracy: 0.9000
# Epoch 59/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2610 - accuracy: 0.8973 - val_loss: 0.2372 - val_accuracy: 0.9040
# Epoch 60/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2716 - accuracy: 0.8966 - val_loss: 0.2780 - val_accuracy: 0.8940
# Epoch 61/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2655 - accuracy: 0.8932 - val_loss: 0.2441 - val_accuracy: 0.8920
# Epoch 62/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2896 - accuracy: 0.8864 - val_loss: 0.2812 - val_accuracy: 0.8740
# Epoch 63/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2630 - accuracy: 0.8904 - val_loss: 0.2458 - val_accuracy: 0.9020
# Epoch 64/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2473 - accuracy: 0.9046 - val_loss: 0.2838 - val_accuracy: 0.9080
# Epoch 65/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2634 - accuracy: 0.8926 - val_loss: 0.2517 - val_accuracy: 0.8980
# Epoch 66/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2562 - accuracy: 0.8970 - val_loss: 0.2381 - val_accuracy: 0.9100
# Epoch 67/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2501 - accuracy: 0.8975 - val_loss: 0.2476 - val_accuracy: 0.8960
# Epoch 68/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2631 - accuracy: 0.8880 - val_loss: 0.2634 - val_accuracy: 0.8800
# Epoch 69/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2562 - accuracy: 0.9047 - val_loss: 0.2605 - val_accuracy: 0.8920
# Epoch 70/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2724 - accuracy: 0.8936 - val_loss: 0.2683 - val_accuracy: 0.8900
# Epoch 71/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2645 - accuracy: 0.8910 - val_loss: 0.2453 - val_accuracy: 0.8980
# Epoch 72/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2756 - accuracy: 0.8941 - val_loss: 0.2563 - val_accuracy: 0.8860
# Epoch 73/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2786 - accuracy: 0.8901 - val_loss: 0.2294 - val_accuracy: 0.9220
# Epoch 74/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2637 - accuracy: 0.8936 - val_loss: 0.2627 - val_accuracy: 0.9020
# Epoch 75/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2560 - accuracy: 0.8993 - val_loss: 0.2999 - val_accuracy: 0.8720
# Epoch 76/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2668 - accuracy: 0.8972 - val_loss: 0.2538 - val_accuracy: 0.9020
# Epoch 77/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2499 - accuracy: 0.9025 - val_loss: 0.2698 - val_accuracy: 0.8900
# Epoch 78/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2594 - accuracy: 0.8965 - val_loss: 0.2367 - val_accuracy: 0.9080
# Epoch 79/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2533 - accuracy: 0.8996 - val_loss: 0.2684 - val_accuracy: 0.8860
# Epoch 80/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2542 - accuracy: 0.8990 - val_loss: 0.2370 - val_accuracy: 0.9120
# Epoch 81/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2712 - accuracy: 0.8888 - val_loss: 0.2395 - val_accuracy: 0.9100
# Epoch 82/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2537 - accuracy: 0.8964 - val_loss: 0.2395 - val_accuracy: 0.9040
# Epoch 83/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2519 - accuracy: 0.9004 - val_loss: 0.2377 - val_accuracy: 0.9040
# Epoch 84/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2464 - accuracy: 0.9012 - val_loss: 0.2719 - val_accuracy: 0.8900
# Epoch 85/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2549 - accuracy: 0.8996 - val_loss: 0.2482 - val_accuracy: 0.9120
# Epoch 86/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2440 - accuracy: 0.8988 - val_loss: 0.2326 - val_accuracy: 0.9040
# Epoch 87/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2656 - accuracy: 0.8943 - val_loss: 0.3167 - val_accuracy: 0.8720
# Epoch 88/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2576 - accuracy: 0.8929 - val_loss: 0.2585 - val_accuracy: 0.8880
# Epoch 89/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2529 - accuracy: 0.8993 - val_loss: 0.2224 - val_accuracy: 0.9240
# Epoch 90/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2373 - accuracy: 0.9111 - val_loss: 0.2689 - val_accuracy: 0.9060
# Epoch 91/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2631 - accuracy: 0.8928 - val_loss: 0.2355 - val_accuracy: 0.9040
# Epoch 92/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2543 - accuracy: 0.8979 - val_loss: 0.2493 - val_accuracy: 0.9040
# Epoch 93/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2483 - accuracy: 0.9056 - val_loss: 0.2222 - val_accuracy: 0.9100
# Epoch 94/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2515 - accuracy: 0.8931 - val_loss: 0.2488 - val_accuracy: 0.8920
# Epoch 95/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2632 - accuracy: 0.8843 - val_loss: 0.2779 - val_accuracy: 0.8880
# Epoch 96/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2581 - accuracy: 0.9051 - val_loss: 0.2435 - val_accuracy: 0.9140
# Epoch 97/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2576 - accuracy: 0.8941 - val_loss: 0.2585 - val_accuracy: 0.9100
# Epoch 98/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2436 - accuracy: 0.9023 - val_loss: 0.2507 - val_accuracy: 0.9080
# Epoch 99/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2567 - accuracy: 0.9004 - val_loss: 0.2460 - val_accuracy: 0.9080
# Epoch 100/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2575 - accuracy: 0.8985 - val_loss: 0.2621 - val_accuracy: 0.8820
# Testing model
# 501/501 [==============================] - 1s 2ms/step - loss: 0.3781 - accuracy: 0.8303
# Done. Test loss: 0.37805095314979553. Test acc: 0.8303393125534058

# %% [markdown]
# ## Plot performance
# Here, we plot the history of the training and the performance in a ROC curve

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#
#print('History type=',history.__dict__)


# Plot loss vs epoch
plt.figure(figsize=(15,10))
ax = plt.subplot(2, 2, 1)
ax.plot(history.history['loss'], label='loss')
ax.plot(history.history['val_loss'], label='val_loss')
ax.legend(loc="upper right")
ax.set_xlabel('epoch')
ax.set_ylabel('loss')

# Plot accuracy vs epoch
ax = plt.subplot(2, 2, 2)
ax.plot(history.history['accuracy'], label='accuracy')
ax.plot(history.history['val_accuracy'], label='val_accuracy')
ax.legend(loc="upper left")
ax.set_xlabel('epoch')
ax.set_ylabel('acc')

'''
# Plot ROC
Y_predict = gatn.predict(loader_te.load())
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
roc_auc = auc(fpr, tpr)
ax = plt.subplot(2, 2, 3)
ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
ax.set_xlim([0, 1.0])
ax.set_ylim([0, 1.0])
ax.set_xlabel('false positive rate')
ax.set_ylabel('true positive rate')
ax.set_title('receiver operating curve')
ax.legend(loc="lower right")
'''

plt.show()

# %% [markdown]
# ### Evaluate the Model
#
# Here we evaluate the model prediction and compare with the target

# %%
'''
# EVALUATE MODEL

y_true = []
y_pred = []
for batch in loader_te:
    input, target = batch
    output = gcn(input, training=False)
    y_true.append(target)
    y_pred.append(output.numpy())

y_true = np.vstack(y_true)
y_pred = np.vstack(y_pred)


# Plot DNN output 
df_sig  = df['sig'].filter(NN_VARS)
df_bkg  = df['bkg'].filter(NN_VARS)

X_sig  = np.asarray( df_sig.values ).astype(np.float32)
X_bkg  = np.asarray( df_bkg.values ).astype(np.float32)

ax = plt.subplot(3, 2, 4)
X = np.linspace(0.0, 1.0, 100)
hist_sig = ax.hist(Y_sig, bins=X, label='sig',histtype='step',lw=LINE_WIDTH)
hist_bkg = ax.hist(Y_bkg, bins=X, label='bkg',histtype='step',lw=LINE_WIDTH)
#ax.hist(Y_train_val, bins=X, label='bkg',histtype='step')
ax.set_xlabel('DNN Output')
ax.legend(prop={'size': 10})


# Plot Eff x Purity

ax = plt.subplot(3, 2, 5)
ax.plot(t, p[:-1], label='purity', lw=LINE_WIDTH)
ax.plot(t, r[:-1], label='efficiency', lw=LINE_WIDTH)
ax.set_xlabel('Cut on model score')
ax.tick_params(width=2, grid_alpha=0.5)
ax.legend()

ax = plt.subplot(3, 2, 6)
ax.plot(t,p[:-1]*r[:-1], lw=LINE_WIDTH)
ax.set_xlabel('Cut on model score')
ax.set_ylabel('Purity*Efficiency')
ax.tick_params(width=2, grid_alpha=0.5)

# Show plots
plt.show()
'''
# Out:
# "\n# EVALUATE MODEL\n\ny_true = []\ny_pred = []\nfor batch in loader_te:\n    input, target = batch\n    output = gcn(input, training=False)\n    y_true.append(target)\n    y_pred.append(output.numpy())\n\ny_true = np.vstack(y_true)\ny_pred = np.vstack(y_pred)\n\n\n# Plot DNN output \ndf_sig  = df['sig'].filter(NN_VARS)\ndf_bkg  = df['bkg'].filter(NN_VARS)\n\nX_sig  = np.asarray( df_sig.values ).astype(np.float32)\nX_bkg  = np.asarray( df_bkg.values ).astype(np.float32)\n\nax = plt.subplot(3, 2, 4)\nX = np.linspace(0.0, 1.0, 100)\nhist_sig = ax.hist(Y_sig, bins=X, label='sig',histtype='step',lw=LINE_WIDTH)\nhist_bkg = ax.hist(Y_bkg, bins=X, label='bkg',histtype='step',lw=LINE_WIDTH)\n#ax.hist(Y_train_val, bins=X, label='bkg',histtype='step')\nax.set_xlabel('DNN Output')\nax.legend(prop={'size': 10})\n\n\n# Plot Eff x Purity\n\nax = plt.subplot(3, 2, 5)\nax.plot(t, p[:-1], label='purity', lw=LINE_WIDTH)\nax.plot(t, r[:-1], label='efficiency', lw=LINE_WIDTH)\nax.set_xlabel('Cut on model score')\nax.tick_params(width=2, grid_alpha=0.5)\nax.legend()\n\nax = plt.subplot(3, 2, 6)\nax.plot(t,p[:-1]*r[:-1], lw=LINE_WIDTH)\nax.set_xlabel('Cut on model score')\nax.set_ylabel('Purity*Efficiency')\nax.tick_params(width=2, grid_alpha=0.5)\n\n# Show plots\nplt.show()\n"
