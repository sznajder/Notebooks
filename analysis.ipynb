# %%
# !pip install uproot
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
dir = '/content/gdrive/My Drive/Bari_Lectures'

import math
import os
import uproot
import numpy as np

# Open the file and get the Root tree
filename=dir+'/events.root'
# !ls 
treename='t'
file = uproot.open(filename)
tree_dict = file[treename].arrays() # dictionary of NumPy arrays
nevt=len(tree_dict)
print("Nevt=",nevt)
print("Keys=",tree_dict.keys())
# Loop over events in a given sample
for event in range(nevt) :

# Define the final state 4 vectors
    
#  mjj = ( p4[1] + p4gj2[2] ).M()


#   Loop over variables to fill histos with event info
  for i in range(len(id)):
    histo.Fill(  )


outFile = "histos.root"
# Out:
# ...
# Mounted at /content/gdrive
# gdrive	sample_data
# Nevt= 10
# Keys= dict_keys([b'id', b'event', b'status', b'parent1', b'parent2', b'color1', b'color2', b'mass', b'spin', b'p4.'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5aed9d17761f> in <module>()
#      27
#      28 #   Loop over variables to fill histos with event info
# ---> 29   for i in range(len(id)):
#      30     histo.Fill(  )
#      31
#
# TypeError: object of type 'builtin_function_or_method' has no len()
